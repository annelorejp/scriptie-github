# %%
# IMPORTS
import requests
import json
from sportmonks.soccer import SoccerApiV2
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, log_loss
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import preprocessing
import xlsxwriter
import excel2json
from datetime import datetime
from sklearn.metrics import accuracy_score,confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus
# Out:
# //anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# //anaconda3/lib/python3.7/site-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
# Sheet1-Copy2.json

# %%
# verwijderen = pd.read_json("Sheet1.json")
data = []
with open('Sheet1.json') as f:
    for line in f:
        print(line)
        data.append(json.loads(line))
# Out:
# [

# %%
from json import JSONDecoder
from functools import partial


def json_parse(fileobj, decoder=JSONDecoder(), buffersize=2048):
    buffer = ''
    for chunk in iter(partial(fileobj.read, buffersize), ''):
        buffer += chunk
        while buffer:
            try:
                result, index = decoder.raw_decode(buffer)
                yield result
                buffer = buffer[index:].lstrip()
            except ValueError:
                # Not enough data to decode, read more
                break


lijst_data = []                

with open('Sheet1-Copy2.json', 'r') as infh:
    for data in json_parse(infh):
        for line in data:
            if line['Crosses'] != 'No':
#                 print('HIER IS DE BITCH')
                lijst_data.append(line)
    
print(lijst_data)
# Out:
# [{'Name': 'Diederik Boer', 'Position': 'G', 'Minutes_played': 90.0, 'Day_since_start': 0.0, 'Crosses': 0.0, 'TacklesWon': 0.0, 'Interceptions': 0.0, 'Fouls': 0.0, 'Fouled': 0.0, 'Passes': 52.9, 'PassesCompleted': 41.4, 'Touches': 62.1, 'BlockedShots': 0.0, 'Injured': 'No'}, {'Name': 'Kingsley Ehizibue', 'Position': 'D', 'Minutes_played': 90.0, 'Day_since_start': 0.0, 'Crosses': 10.4, 'TacklesWon': 1.3, 'Interceptions': 0.0, 'Fouls': 2.6, 'Fouled': 4.0, 'Passes': 48.3, 'PassesCompleted': 42.6, 'Touches': 86.2, 'BlockedShots': 0.0, 'Injured': 'No'}, {'Name': 'Darryl Lachman', 'Position': 'D', 'Minutes_played': 90.0, 'Day_since_start': 0.0, 'Crosses': 0.0, 'TacklesWon': 1.3, 'Interceptions': 0.0, 'Fouls': 2.6, 'Fouled': 1.3, 'Passes': 110.4, 'PassesCompleted': 98.9, 'Touches': 118.4, 'BlockedShots': 0.0, 'Injured': 'No'}, {'Name': 'Dirk Marcellis', 'Position': 'D', 'Minutes_played': 90.0, 'Day_since_start': 0.0, 'Crosses': 1.3, 'TacklesWon': 0.0, 'Interceptions': 2.6, 'Fouls': 1.3, 'Fou
# ...

# %%
import json

with open('Sheet1-Copy2.json') as data_file:
    data = json.load(data_file)

for element in data:
    if element['Crosses'] == 'No':
        del element

with open('Sheet1-Copy2.json', 'w') as data_file:
    data = json.dump(data, data_file)

# with open('data.json', 'w') as data_file:
#     data = json.dump(data, data_file)


# for element in data:
#     if 'hours' in element:
#         del element['hours']

# with open('data.json', 'w') as data_file:
#     data = json.dump(data, data_file)
