# %%
# IMPORTS
import requests
import json
from sportmonks.soccer import SoccerApiV2
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, log_loss
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import preprocessing
import xlsxwriter
import excel2json
from datetime import datetime
from sklearn.metrics import accuracy_score,confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus
# Out:
# //anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# //anaconda3/lib/python3.7/site-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
# JSON FORMAT PRINT
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# %%
# API key
soccer = SoccerApiV2(api_token='kDasthE00jpkFjEERAZNFyE9a79LNX3tPeaAqlhB3s2NhckJbKDhyL94j7AO')

# %%
# START AND END DATE 
start_date = "2018-08-10"
end_date = "2019-05-12"

# EMPTY LIST FOR ALL THE VARIABLES
lijst = []
sub_list = []
sub_list_min = []

# START QUERY
ids = soccer.fixtures(start_date, end_date, includes=('lineup', 'substitutions', 'venue'))

# CHANGE THIS LIST TO THE FEATURES YOU APPED
inhoud = ['Name', 'Position', 'Minutes_played', 'Day_since_start', 'Country', 'Injured'] 
# inhoud = ['Position', 'Minutes_played', 'Day_since_start', 'Venue', 'Injured'] 
lijst.append(inhoud)

# FOR LOOP TO GET ALL THE FIXTURES IN BETWEEN THE START AND END DATE
for f in ids:
    team = []
    index = 0
    
    # WHILE LOOP TO GET EVERY PLAYER OF THE LINEUP
    while len(team) < len(f['lineup']):
        speler = []
        minutes = 0
        
        # STANDARD FEATURES (name, position, minutes played, day since start date, injury)
        
        # NAME PLAYER
        name = f['lineup'][index]['player_name']
        speler.append(name)
        team.append(speler)   
    
        # POSITION PLAYER
        position = f['lineup'][index]['position']
        speler.append(position)
        
        # MINUTES PLAYED
        minutes = f['lineup'][index]['stats']['other']['minutes_played']
        if minutes == None:
            minutes = 0
        speler.append(minutes)
        
        # DAY SINCE START DATE
        current_date = f["time"]["starting_at"]["date"]
        date_format = "%Y-%m-%d"
        a = datetime.strptime(start_date, date_format)
        b = datetime.strptime(current_date, date_format)
        delta = b - a
        speler.append(delta.days)
        
        
        # VARIABLE FEATURES 
        
        # COUNTRY
        id_player = f['lineup'][index]['player_id']
        team_player = f['lineup'][index]['team_id']

        player = soccer.player(id_player)
        birth_country = player['birthcountry']

        team_of_player = soccer.team(team_player, includes=('country'))
        country_team = team_of_player['country']['name']

        if birth_country == country_team:
            speler.append('Same')
        else:
            speler.append('Different')
        
        
        
        
        # TARGET VALUE IF THE PLAYER IS INJURED
        
        # INJURY
        injury_index = 0 
        injured = 'null'
        while injury_index < len(f['substitutions']):
            sub = []
            player_name = name.split(' ')
            sub_name = f['substitutions'][injury_index]['player_out_name']
            sub_name_split = sub_name.split(' ')  
            if player_name[-1] == sub_name_split[-1]:
                injured = f['substitutions'][injury_index]['injuried']
                break
            else:
                injury_index += 1
        if injured == True :
            speler.append('Yes')
        else:
            speler.append('No')
        
        # APPEND THE PLAYER TO THE BIG LIST
        lijst.append(speler)
        index += 1


print(lijst)
# Out:
# [['Name', 'Position', 'Minutes_played', 'Day_since_start', 'Country', 'Injured'], ['Diederik Boer', 'G', 90, 0, 'Same', 'No'], ['Kingsley Ehizibue', 'D', 90, 0, 'Different', 'No'], ['Darryl Lachman', 'D', 90, 0, 'Same', 'No'], ['Dirk Marcellis', 'D', 90, 0, 'Same', 'No'], ['Bram Van Polen', 'D', 90, 0, 'Same', 'No'], ['Gustavo Hamer', 'M', 90, 0, 'Different', 'No'], ['Clint Leemans', 'M', 90, 0, 'Same', 'No'], ['Denis Genreau', 'M', 46, 0, 'Different', 'No'], ['Zian Flemming', 'M', 87, 0, 'Same', 'No'], ['Vito van Crooy', 'A', 90, 0, 'Same', 'No'], ['Mike van Duinen', 'A', 90, 0, 'Same', 'No'], ['Warner Hahn', 'G', 90, 0, 'Same', 'No'], ['Doke Schmidt', 'D', 90, 0, 'Same', 'No'], ['Daniel Høegh', 'D', 90, 0, 'Different', 'No'], ['Dave Bulthuis', 'D', 90, 0, 'Same', 'No'], ['Kik Pierie', 'D', 90, 0, 'Different', 'No'], ['Morten Thorsby', 'M', 55, 0, 'Different', 'No'], ['Yuki Kobayashi', 'M', 90, 0, 'Different', 'No'], ['Michel Vlap', 'M', 87, 0, 'Same', 'No'], ['Nemanja Mihajlović', 'A', 59, 0, 'Different', 'No'], ['Sam Lammers', 'A', 90, 0, 'Same', 'No'], ['Arbër Zeneli', 'A', 66, 0, 'Different', 'No'], ['T. Wellenreuther', 'G', 90, 1, 'Different', 'No'], ['D. Dankerlui', 'D', 90, 1, 'Same', 'No'], ['F. Lewis', 'D', 90, 1, 'Same', 'No'], ['F. Heerkens', 'D', 90, 1, 'Same', 'No'], ['J. Mcgarry', 'M', 63, 1, 'Different', 'No'], ['Pol Llonch', 'M', 76, 1, 'Different', 'Yes'], ['D. Crowley', 'M', 90, 1, 'Different', 'No'], ['E. Lieftink', 'M', 90, 1, 'Same', 'No'], ['J. Croux', 'A', 90, 1, 'Different', 'No'], ['Fran Sol', 'A', 90, 1, 'Different', 'No'], ['D. Palacios', 'D', 90, 1, 'Different', 'No'], ['L. Unnerstall', 'G', 90, 1, 'Different', 'No'], ['C. Kum', 'D', 90, 1, 'Different', 'No'], ['J. Promes', 'D', 90, 1, 'Same', 'No'], ['N. Röseler', 'D', 90, 1, 'Different', 'No'], ['R. Janssen', 'D', 90, 1, 'Same', 'No'], ['M. Rutten', 'D', 90, 1, 'Same', 'No'], ['D. Post', 'M', 90, 1, 'Same', 'No'], ['T. Sušić', 'M', 90, 1, 'Different', 'No'], ['P. van Ooijen', 'M', 74, 1, 'Same', 'No'], ['R. Seuntjens', 'M', 65, 1, 'Same', 'No'], ['M. Samuelsen', 'M', 82, 1, 'Different', 'No'], ['A. Onana', 'G', 90, 1, 'Different', 'No'], ['N. Mazraoui', 'D', 90, 1, 'Same', 'No'], ['M. de Ligt', 'D', 90, 1, 'Same', 'No'], ['D. Blind', 'D', 90, 1, 'Same', 'No'], ['M. Wöber', 'D', 56, 1, 'Different', 'Yes'], ['C. Eiting', 'M', 90, 1, 'Same', 'No'], ['H. Ziyech', 'M', 90, 1, 'Same', 'No'], ['D. van de Beek', 'M', 90, 1, 'Same', 'No'], ['D. Tadić', 'M', 90, 1, 'Different', 'No'], ['K. Sierhuis', 'A', 56, 1, 'Different', 'No'], ['David Neres', 'A', 85, 1, 'Different', 'No'], ['J. Blaswich', 'G', 90, 1, 'Different', 'No'], ['W. Droste', 'D', 79, 1, 'Same', 'No'], ['M. Rossmann', 'D', 90, 1, 'Different', 'No'], ['R. Pröpper', 'D', 90, 1, 'Same', 'No'], ['B. van Hintum', 'D', 82, 1, 'Same', 'No'], ['M. Osman', 'M', 90, 1, 'Different', 'No'], ['L. Duarte', 'M', 90, 1, 'Same', 'No'], ['Y. van Nieff', 'D', 90, 1, 'Same', 'No'], ['B. Kuwas', 'A', 77, 1, 'Same', 'No'], ['Adrián Dalmau', 'A', 90, 1, 'Different', 'No'], ['K. Peterson', 'A', 90, 1, 'Different', 'No'], ['J. Zoet', 'G', 90, 1, 'Same', 'No'], ['D. Dumfries', 'D', 90, 1, 'Same', 'No'], ['D. Schwaab', 'D', 90, 1, 'Different', 'No'], ['N. Viergever', 'D', 90, 1, 'Same', 'No'], ['Angeliño', 'D', 90, 1, 'Different', 'No'], ['P. Rosario', 'M', 67, 1, 'Same', 'No'], ['G. Pereiro', 'M', 81, 1, 'Different', 'No'], ['J. Hendrix', 'M', 90, 1, 'Same', 'No'], ['S. Bergwijn', 'A', 86, 1, 'Same', 'No'], ['L. de Jong', 'A', 90, 1, 'Different', 'No'], ['H. Lozano', 'A', 90, 1, 'Different', 'No'], ['D. Jensen', 'G', 90, 1, 'Different', 'No'], ['G. Troupée', 'D', 71, 1, 'Same', 'No'], ['R. Leeuwin', 'D', 90, 1, 'Same', 'No'], ['W. Janssen', 'D', 90, 1, 'Same', 'No'], ['M. van der Maarel', 'D', 90, 1, 'Same', 'No'], ['L. Guwara', 'D', 90, 1, 'Different', 'No'], ['S. Klaiber', 'D', 90, 1, 'Same', 'No'], ['Simon Gustafson', 'M', 90, 1, 'Different', 'No'], ['U. Emanuelson', 'M', 81, 1, 'Same', 'Yes'], ['S. van de Streek', ...

# %%
# CODE TO EXPORT TO EXCEL 
with xlsxwriter.Workbook('ajaxcountry.xlsx') as workbook:
    worksheet = workbook.add_worksheet()

    for row_num, data in enumerate(lijst):
        worksheet.write_row(row_num, 0, data)

# CODE TO CONVERT EXCEL FILE TO JSON --> (Sheet1.json)
excel2json.convert_from_file('ajaxcountry.xlsx')

# %%
# READ THE JOSN FILE AND PRINT HEAD
ajax = pd.read_json("Sheet1.json")
print(ajax)
# Out:
#                   Name Position  Minutes_played  Day_since_start    Country  \
# 0        Diederik Boer        G              90                0       Same
# 1    Kingsley Ehizibue        D              90                0  Different
# 2       Darryl Lachman        D              90                0       Same
# 3       Dirk Marcellis        D              90                0       Same
# 4       Bram Van Polen        D              90                0       Same
# ..                 ...      ...             ...              ...        ...
# 587         Matúš Bero        M              75               16  Different
# 588      Navarone Foor        M              90               16       Same
# 589        Roy Beerens        A              65               16       Same
# 590         Tim Matavz        A              79               16  Different
# 591      Bryan Linssen        A              90               16       Same
#
#     Injured
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
# ..      ...
# 587      No
# 588      No
# 589      No
# 590      No
# 591      No
#
# [592 rows x 6 columns]

# %%
# inhoud = ['Name', 'Position', 'Minutes_played', 'Day_since_start', 'Injuried', 'Venue'] 

le = preprocessing.LabelEncoder()

ajax['Name'] = le.fit_transform(ajax['Name'])
ajax['Position'] = le.fit_transform(ajax['Position'])
ajax['Country'] = le.fit_transform(ajax['Country'])
ajax['Injured'] = le.fit_transform(ajax['Injured'])

# %%
Y = ajax.Injured
X = ajax.drop('Injured', axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
X_train_val, X_val, y_train_val, y_val = train_test_split(X_train, y_train, test_size=0.2)

# %%
classifier = DecisionTreeClassifier(random_state=0, max_depth=None)
classifier.fit(X_train_val, y_train_val)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %%
# PREDICT VALIDATION
y_pred = classifier.predict(X_val)

# %%
# PRINT ACCURACY SCORE
print(accuracy_score(y_val, y_pred))
# Out:
# 0.9263157894736842

# %%
# # TRANSFORM LABELS BACK TO ORIGINAL ENCODING
# print(ajax['Injured'])
ajax['Injured'] = le.inverse_transform(ajax['Injured'])
# print(ajax['Injured'])

# %%
# PRINT CONFUSION MATRIX
features = ajax['Injured'].unique()
confusion = pd.DataFrame(confusion_matrix(y_val, y_pred),columns=features,index=features)
plt.figure(figsize=(5,4))
sns.heatmap(confusion,annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# PREDICT TEST 
y_pred = classifier.predict(X_test)

# %%
# PRINT ACCURACY SCORE
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9327731092436975

# %%
# PRINT CONFUSION MATRIX
features = ajax['Injured'].unique()
confusion=pd.DataFrame(confusion_matrix(y_test,y_pred),columns=features,index=features)
plt.figure(figsize=(5,4))
sns.heatmap(confusion,annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
feature_cols = ['Name', 'Position', 'Minutes_played', 'Day_since_start', 'Country'] 

dot_data = StringIO()
export_graphviz(classifier, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names = feature_cols, class_names=['No','Yes'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('predictions.png')
Image(graph.create_png())

# %%
# start_date = "2018-08-10"
# end_date = "2018-08-10"

# ids = soccer.fixtures(start_date, end_date, includes=('lineup', 'substitutions', 'venue'))


# for f in ids:
#     id_player = f['lineup'][0]['player_id']
#     team_player = f['lineup'][0]['team_id']

#     player = soccer.player(id_player)
#     birth_country = player['birthcountry']
    
#     team = soccer.team(team_player, includes=('country'))
#     country_team = team['country']['name']
    
#     if birth_country == country_team:
#         print('same')
#     else:
#         print('different')
# #         speler.append('same')

# %%
# info = soccer.player(25187)
# print(info)
