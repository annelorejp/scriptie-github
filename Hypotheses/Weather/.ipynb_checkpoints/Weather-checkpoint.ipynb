# %%
# IMPORTS
import requests
import json
from sportmonks.soccer import SoccerApiV2
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, log_loss
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import preprocessing
import xlsxwriter
import excel2json
from datetime import datetime
from sklearn.metrics import accuracy_score,confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus
# Out:
# //anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# //anaconda3/lib/python3.7/site-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
# JSON FORMAT PRINT
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# %%
# API key
soccer = SoccerApiV2(api_token='kDasthE00jpkFjEERAZNFyE9a79LNX3tPeaAqlhB3s2NhckJbKDhyL94j7AO')

# %%
# START AND END DATE 
start_date = "2018-08-10"
end_date = "2019-05-12"

# EMPTY LIST FOR ALL THE VARIABLES
lijst = []
sub_list = []
sub_list_min = []

# START QUERY
ids = soccer.fixtures(start_date, end_date, includes=('lineup', 'substitutions', 'venue'))

# CHANGE THIS LIST TO THE FEATURES YOU APPED
inhoud = ['Name', 'Position', 'Minutes_played', 'Day_since_start', 'Weather_code', 'Weather_humidity', 'Weather_temp', 'Injured'] 
# inhoud = ['Position', 'Minutes_played', 'Day_since_start', 'Venue', 'Injured'] 
lijst.append(inhoud)

# FOR LOOP TO GET ALL THE FIXTURES IN BETWEEN THE START AND END DATE
for f in ids:
    team = []
    index = 0
    
    # WHILE LOOP TO GET EVERY PLAYER OF THE LINEUP
    while len(team) < len(f['lineup']):
        speler = []
        minutes = 0
        
        # STANDARD FEATURES (name, position, minutes played, day since start date, injury)
        
        # NAME PLAYER
        name = f['lineup'][index]['player_name']
        speler.append(name)
        team.append(speler)   
    
        # POSITION PLAYER
        position = f['lineup'][index]['position']
        speler.append(position)
        
        # MINUTES PLAYED
        minutes = f['lineup'][index]['stats']['other']['minutes_played']
        if minutes == None:
            minutes = 0
        speler.append(minutes)
        
        # DAY SINCE START DATE
        current_date = f["time"]["starting_at"]["date"]
        date_format = "%Y-%m-%d"
        a = datetime.strptime(start_date, date_format)
        b = datetime.strptime(current_date, date_format)
        delta = b - a
        speler.append(delta.days)
        
        
        # VARIABLE FEATURES 
        
        # WEATHER
        if f['weather_report'] != None:
            weather_code = f['weather_report']['code']
            hum = f['weather_report']['humidity']
            humidity = hum[:-1]
            weather_humidity = float(humidity)
            weather_temp = f['weather_report']['temperature']['temp']
            speler.append(weather_code)
            speler.append(weather_humidity)
            speler.append(weather_temp)
        else:
            speler.append('None')
            speler.append(0)
            speler.append(0)
        
        
        # TARGET VALUE IF THE PLAYER IS INJURED
        
        # INJURY
        injury_index = 0 
        injured = 'null'
        while injury_index < len(f['substitutions']):
            sub = []
            player_name = name.split(' ')
            sub_name = f['substitutions'][injury_index]['player_out_name']
            sub_name_split = sub_name.split(' ')  
            if player_name[-1] == sub_name_split[-1]:
                injured = f['substitutions'][injury_index]['injuried']
                break
            else:
                injury_index += 1
        if injured == True :
            speler.append('Yes')
        else:
            speler.append('No')
        
        # APPEND THE PLAYER TO THE BIG LIST
        lijst.append(speler)
        index += 1


print(lijst)
# Out:
# 90
# 90
# 90
# 90
# None
# ik kom hier
# 80
# 90
# 90
# 90
# 90
# 90
# 90
# 90
# 90
# [['Name', 'Position', 'Minutes_played', 'Day_since_start', 'Weather_code', 'Weather_humidity', 'Weather_temp', 'Injured'], ['Diederik Boer', 'G', 90, 0, 'clouds', 46.0, 69.8, 'No'], ['Kingsley Ehizibue', 'D', 90, 0, 'clouds', 46.0, 69.8, 'No'], ['Darryl Lachman', 'D', 90, 0, 'clouds', 46.0, 69.8, 'No'], ['Dirk Marcellis', 'D', 90, 0, 'clouds', 46.0, 69.8, 'No'], ['Bram Van Polen', 'D', 90, 0, 'clouds', 46.0, 69.8, 'No'], ['Gustavo Hamer', 'M', 90, 0, 'clouds', 46.0, 69.8, 'No'], ['Clint Leemans', 'M', 90, 0, 'clouds', 46.0, 69.8, 'No'], ['Denis Genreau', 'M', 46, 0, 'clouds', 46.0, 69.8, 'No'], ['Zian Flemming', 'M', 87, 0, 'clouds', 46.0, 69.8, 'No'], ['Vito van Crooy', 'A', 90, 0, 'clouds', 46.0, 69.8, 'No'], ['Mike van Duinen', 'A', 90, 0, 'clouds', 46.0, 69.8, 'No'], ['Warner Hahn', 'G', 90, 0, 'clouds', 46.0, 69.8, 'No'], ['Doke Schmidt', 'D', 90, 0, 'clouds', 46.0, 69.8, 'No'], ['Daniel Høegh', 'D', 90, 0, 'clouds', 46.0, 69.8, 'No'], ['Dave Bulthuis', 'D', 90, 0, 'clouds', 46.0, 69.8, 'No'], ['Kik Pierie', 'D', 90, 0, 'clouds', 46.0, 69.8, 'No'], ['Morten Thorsby', 'M', 55, 0, 'clouds', 46.0, 69.8, 'No'], ['Yuki Kobayashi', 'M', 90, 0, 'clouds', 46.0, 69.8, 'No'], ['Michel Vlap', 'M', 87, 0, 'clouds', 46.0, 69.8, 'No'], ['Nemanja Mihajlović', 'A', 59, 0, 'clouds', 46.0, 69.8, 'No'], ['Sam Lammers', 'A', 90, 0, 'clouds', 46.0, 69.8, 'No'], ['Arbër Zeneli', 'A', 66, 0, 'clouds', 46.0, 69.8, 'No'], ['T. Wellenreuther', 'G', 90, 1, 'clouds', 40.0, 69.35, 'No'], ['D. Dankerlui', 'D', 90, 1, 'clouds', 40.0, 69.35, 'No'], ['F. Lewis', 'D', 90, 1, 'clouds', 40.0, 69.35, 'No'], ['F. Heerkens', 'D', 90, 1, 'clouds', 40.0, 69.35, 'No'], ['J. Mcgarry', 'M', 63, 1, 'clouds', 40.0, 69.35, 'No'], ['Pol Llonch', 'M', 76, 1, 'clouds', 40.0, 69.35, 'Yes'], ['D. Crowley', 'M', 90, 1, 'clouds', 40.0, 69.35, 'No'], ['E. Lieftink', 'M', 90, 1, 'clouds', 40.0, 69.35, 'No'], ['J. Croux', 'A', 90, 1, 'clouds', 40.0, 69.35, 'No'], ['Fran Sol', 'A', 90, 1, 'clouds', 40.0, 69.35, 'No'], ['D. Palacios', 'D', 90, 1, 'clouds', 40.0, 69.35, 'No'], ['L. Unnerstall', 'G', 90, 1, 'clouds', 40.0, 69.35, 'No'], ['C. Kum', 'D', 90, 1, 'clouds', 40.0, 69.35, 'No'], ['J. Promes', 'D', 90, 1, 'clouds', 40.0, 69.35, 'No'], ['N. Röseler', 'D', 90, 1, 'clouds', 40.0, 69.35, 'No'], ['R. Janssen', 'D', 90, 1, 'clouds', 40.0, 69.35, 'No'], ['M. Rutten', 'D', 90, 1, 'clouds', 40.0, 69.35, 'No'], ['D. Post', 'M', 90, 1, 'clouds', 40.0, 69.35, 'No'], ['T. Sušić', 'M', 90, 1, 'clouds', 40.0, 69.35, 'No'], ['P. van Ooijen', 'M', 74, 1, 'clouds', 40.0, 69.35, 'No'], ['R. Seuntjens', 'M', 65, 1, 'clouds', 40.0, 69.35, 'No'], ['M. Samuelsen', 'M', 82, 1, 'clouds', 40.0, 69.35, 'No'], ['A. Onana', 'G', 90, 1, 'clouds', 55.0, 65.01, 'No'], ['N. Mazraoui', 'D', 90, 1, 'clouds', 55.0, 65.01, 'No'], ['M. de Ligt', 'D', 90, 1, 'clouds', 55.0, 65.01, 'No'], ['D. Blind', 'D', 90, 1, 'clouds', 55.0, 65.01, 'No'], ['M. Wöber', 'D', 56, 1, 'clouds', 55.0, 65.01, 'Yes'], ['C. Eiting', 'M', 90, 1, 'clouds', 55.0, 65.01, 'No'], ['H. Ziyech', 'M', 90, 1, 'clouds', 55.0, 65.01, 'No'], ['D. van de Beek', 'M', 90, 1, 'clouds', 55.0, 65.01, 'No'], ['D. Tadić', 'M', 90, 1, 'clouds', 55.0, 65.01, 'No'], ['K. Sierhuis', 'A', 56, 1, 'clouds', 55.0, 65.01, 'No'], ['David Neres', 'A', 85, 1, 'clouds', 55.0, 65.01, 'No'], ['J. Blaswich', 'G', 90, 1, 'clouds', 55.0, 65.01, 'No'], ['W. Droste', 'D', 79, 1, 'clouds', 55.0, 65.01, 'No'], ['M. Rossmann', 'D', 90, 1, 'clouds', 55.0, 65.01, 'No'], ['R. Pröpper', 'D', 90, 1, 'clouds', 55.0, 65.01, 'No'], ['B. van Hintum', 'D', 82, 1, 'clouds', 55.0, 65.01, 'No'], ['M. Osman', 'M', 90, 1, 'clouds', 55.0, 65.01, 'No'], ['L. Duarte', 'M', 90, 1, 'clouds', 55.0, 65.01, 'No'], ['Y. van Nieff', 'D', 90, 1, 'clouds', 55.0, 65.01, 'No'], ['B. Kuwas', 'A', 77, 1, 'clouds', 55.0, 65.01, 'No'], ['Adrián Dalmau', 'A', 90, 1, 'clouds', 55.0, 65.01, 'No'], ['K. Peterson', 'A', 90, 1, 'clouds', 55.0, 65.01, 'No'], ['J. Zoet', 'G', 90, 1, 'clouds', 46.0, 69.3, 'No'], ['D.  ...

# %%
# CODE TO EXPORT TO EXCEL 
with xlsxwriter.Workbook('ajaxweather.xlsx') as workbook:
    worksheet = workbook.add_worksheet()

    for row_num, data in enumerate(lijst):
        worksheet.write_row(row_num, 0, data)

# CODE TO CONVERT EXCEL FILE TO JSON --> (Sheet1.json)
excel2json.convert_from_file('ajaxweather.xlsx')

# %%
# READ THE JOSN FILE AND PRINT HEAD
ajax = pd.read_json("Sheet1.json")
print(ajax)
# Out:
#                     Name Position  Minutes_played  Day_since_start  \
# 0          Diederik Boer        G              90                0
# 1      Kingsley Ehizibue        D              90                0
# 2         Darryl Lachman        D              90                0
# 3         Dirk Marcellis        D              90                0
# 4         Bram Van Polen        D              90                0
# ...                  ...      ...             ...              ...
# 6513      José Rodríguez        M              90              275
# 6514       Jorrit Smeets        M              90              275
# 6515        Mark Diemers        M              76              275
# 6516       Finn Stokkers        A              90              275
# 6517  Andrija Novakovich        A              64              275
#
#      Weather_code  Weather_humidity  Weather_temp Injured
# 0          clouds                46         69.80      No
# 1          clouds                46         69.80      No
# 2          clouds                46         69.80      No
# 3          clouds                46         69.80      No
# 4          clouds                46         69.80      No
# ...           ...               ...           ...     ...
# 6513       clouds                50         55.45      No
# 6514       clouds                50         55.45      No
# 6515       clouds                50         55.45      No
# 6516       clouds                50         55.45      No
# 6517       clouds                50         55.45      No
#
# [6518 rows x 8 columns]

# %%
# inhoud = ['Name', 'Position', 'Minutes_played', 'Day_since_start', 'Injuried', 'Venue'] 

le = preprocessing.LabelEncoder()

ajax['Name'] = le.fit_transform(ajax['Name'])
ajax['Position'] = le.fit_transform(ajax['Position'])
ajax['Weather_code'] = le.fit_transform(ajax['Weather_code'])
# ajax['Weather_humidity'] = le.fit_transform(ajax['Weather_humidity'])
# ajax['Weather_temp'] = le.fit_transform(ajax['Weather_temp'])
ajax['Injured'] = le.fit_transform(ajax['Injured'])

# %%
Y = ajax.Injured
X = ajax.drop('Injured', axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
X_train_val, X_val, y_train_val, y_val = train_test_split(X_train, y_train, test_size=0.2)

# %%
classifier = DecisionTreeClassifier(random_state=0, max_depth=None)
classifier.fit(X_train_val, y_train_val)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %%
# PREDICT VALIDATION
y_pred = classifier.predict(X_val)

# %%
# PRINT ACCURACY SCORE
print(accuracy_score(y_val, y_pred))
# Out:
# 0.9827420901246404

# %%
# # TRANSFORM LABELS BACK TO ORIGINAL ENCODING
# print(ajax['Injured'])
ajax['Injured'] = le.inverse_transform(ajax['Injured'])
# print(ajax['Injured'])

# %%
# PRINT CONFUSION MATRIX
features = ajax['Injured'].unique()
confusion = pd.DataFrame(confusion_matrix(y_val, y_pred),columns=features,index=features)
plt.figure(figsize=(5,4))
sns.heatmap(confusion,annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# PREDICT TEST 
y_pred = classifier.predict(X_test)

# %%
# PRINT ACCURACY SCORE
print(accuracy_score(y_test, y_pred))
# Out:
# 0.973159509202454

# %%
# PRINT CONFUSION MATRIX
features = ajax['Injured'].unique()
confusion=pd.DataFrame(confusion_matrix(y_test,y_pred),columns=features,index=features)
plt.figure(figsize=(5,4))
sns.heatmap(confusion,annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
feature_cols = ['Name', 'Position', 'Minutes_played', 'Day_since_start', 'Weather_code', 'Weather_humidity', 'Weather_temp'] 

dot_data = StringIO()
export_graphviz(classifier, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names = feature_cols, class_names=['No','Yes'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('predictions.png')
Image(graph.create_png())

# %%
# start_date = "2018-08-10"
# end_date = "2018-08-10"

# ids = soccer.fixtures(start_date, end_date, includes=('lineup', 'substitutions', 'venue'))

# for f in ids:
#     print(type(f['weather_report']['temperature']['temp']))
