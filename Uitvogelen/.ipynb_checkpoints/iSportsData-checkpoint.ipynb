# %%
# http://api.isportsapi.com/sport/football/livescores?api_key=<YOUR_API_KEY>

# key = YnmqwhlI6qxrKyKN

#http://api.isportsapi.com/sport/football/playerstats/match?api_key=<YOUR_API_KEY>&matchId=376243710

#{"teamId":"253","leagueId":"1617","name":"AFC Ajax"

# %%
# JSON FORMAT PRINT
import json
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# %%
import urllib.request

    # Set url parameter
url = "http://api.isportsapi.com/sport/football/schedule/basic?api_key=YnmqwhlI6qxrKyKN&leagueId=1617"
# Call iSport Api to get data in json format
f = urllib.request.urlopen(url)
content = f.read()

uitslag = content.decode('utf-8')


for i in uitslag['data']:
    nummer = i["matchId"]
    print(nummer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-e31c0b910352> in <module>
#       9 uitslag = content.decode('utf-8')
#      10
# ---> 11 for i in uitslag['data']:
#      12     nummer = i["matchId"]
#      13     print(nummer)
#
# TypeError: string indices must be integers

# %%
# url = "http://api.isportsapi.com/sport/football/playerstats/match?api_key=YnmqwhlI6qxrKyKN&matchId=376243710"

import urllib.request

# Set url parameter
url = "http://api.isportsapi.com/sport/football/playerstats/match?api_key=YnmqwhlI6qxrKyKN&matchId=376243710"

# Call iSport Api to get data in json format
f = urllib.request.urlopen(url)
content = f.read()

print(content.decode('utf-8'))
# Out:
# {"code":0,"message":"success","data":[]}

# %%
import urllib.request

def SportDemo():
    # Set url parameter
    url = "http://api.isportsapi.com/sport/football/playerstats/match?api_key=YnmqwhlI6qxrKyKN&matchId=379332712"

    # Call iSport Api to get data in json format
    f = urllib.request.urlopen(url)
    content = f.read()

    print(content.decode('utf-8'))


SportDemo()
# Out:
# {"code":0,"message":"success","data":[]}

# %%
import requests
import json

URL = "http://api.isportsapi.com/sport/football/schedule/basic?api_key=YnmqwhlI6qxrKyKN&leagueId=1617"

response = requests.get(URL)
# print(response.status_code)
# print()
uitslag = response.json()['data']

for i in uitslag:
    nummer = i["matchId"]
    print(nummer)
    url_match = "http://api.isportsapi.com/sport/football/playerstats/match?api_key=YnmqwhlI6qxrKyKN&matchId=" + nummer
    response_2 = requests.get(url_match)
    print(response.status_code)
    player_stats = response_2.json()
    print(player_stats)
# Out:
# 379332712
# <class 'str'>
# 200
# {'code': 0, 'message': 'success', 'data': []}
# 399332714
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-e45c10525e91> in <module>
#      14     print(type(nummer))
# ...

# %%
# {"code":0,"message":"success","data":[{"matchId":"379332712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1574530200,"status":-1,"homeName":"FC Utrecht","awayName":"AZ Alkmaar","homeScore":0,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"399332714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1574534700,"status":-1,"homeName":"PEC Zwolle","awayName":"Fortuna Sittard","homeScore":3,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"100432717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1574534700,"status":-1,"homeName":"AFC Ajax","awayName":"Heracles Almelo","homeScore":4,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"110432718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1574538300,"status":-1,"homeName":"ADO Den Haag","awayName":"Willem II","homeScore":3,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"120432719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1574594100,"status":-1,"homeName":"Groningen","awayName":"Feyenoord","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"230432710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1574602200,"status":-1,"homeName":"RKC Waalwijk","awayName":"Emmen","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"389332713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1574602200,"status":-1,"homeName":"PSV Eindhoven","awayName":"SC Heerenveen","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"250432712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1574610300,"status":-1,"homeName":"Sparta Rotterdam","awayName":"Vitesse Arnhem","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"240432711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1574610300,"status":-1,"homeName":"VVV Venlo","awayName":"FC Twente Enschede","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"260432713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575054000,"status":-1,"homeName":"SC Heerenveen","awayName":"Vitesse Arnhem","homeScore":3,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"270432714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575135000,"status":-1,"homeName":"Willem II","awayName":"Sparta Rotterdam","homeScore":4,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"280432715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575139500,"status":-1,"homeName":"Fortuna Sittard","awayName":"Groningen","homeScore":1,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"101432718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575143100,"status":-1,"homeName":"Heracles Almelo","awayName":"ADO Den Haag","homeScore":4,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"221432710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575198900,"status":-1,"homeName":"FC Twente Enschede","awayName":"AFC Ajax","homeScore":2,"awayScore":5,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"241432712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575207000,"status":-1,"homeName":"FC Utrecht","awayName":"RKC Waalwijk","homeScore":0,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"231432711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575215100,"status":-1,"homeName":"AZ Alkmaar","awayName":"VVV Venlo","homeScore":1,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":true},{"matchId":"111432719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575215100,"status":-1,"homeName":"Feyenoord","awayName":"PEC Zwolle","homeScore":1,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"290432716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575226800,"status":-1,"homeName":"Emmen","awayName":"PSV Eindhoven","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"261432714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575659700,"status":-1,"homeName":"AFC Ajax","awayName":"Willem II","homeScore":0,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"271432715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575739800,"status":-1,"homeName":"ADO Den Haag","awayName":"FC Twente Enschede","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"291432717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575744300,"status":-1,"homeName":"VVV Venlo","awayName":"Emmen","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"281432716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575744300,"status":-1,"homeName":"PSV Eindhoven","awayName":"Fortuna Sittard","homeScore":5,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"251432713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575747900,"status":-1,"homeName":"PEC Zwolle","awayName":"AZ Alkmaar","homeScore":0,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"102432719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575803700,"status":-1,"homeName":"Vitesse Arnhem","awayName":"Feyenoord","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"212432710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575811800,"status":-1,"homeName":"RKC Waalwijk","awayName":"SC Heerenveen","homeScore":1,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"222432711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575811800,"status":-1,"homeName":"Groningen","awayName":"FC Utrecht","homeScore":0,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"232432712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1575819900,"status":-1,"homeName":"Sparta Rotterdam","awayName":"Heracles Almelo","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"242432713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1576263600,"status":-1,"homeName":"SC Heerenveen","awayName":"Willem II","homeScore":1,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"252432714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1576344600,"status":-1,"homeName":"ADO Den Haag","awayName":"Groningen","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"262432715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1576349100,"status":-1,"homeName":"Fortuna Sittard","awayName":"RKC Waalwijk","homeScore":3,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"272432716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1576349100,"status":-1,"homeName":"VVV Venlo","awayName":"PEC Zwolle","homeScore":1,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"282432717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1576352700,"status":-1,"homeName":"FC Twente Enschede","awayName":"Vitesse Arnhem","homeScore":0,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"213432711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1576408500,"status":-1,"homeName":"Emmen","awayName":"Sparta Rotterdam","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"203432710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1576416600,"status":-1,"homeName":"Feyenoord","awayName":"PSV Eindhoven","homeScore":3,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"292432718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1576424700,"status":-1,"homeName":"AZ Alkmaar","awayName":"AFC Ajax","homeScore":1,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"223432712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1576424700,"status":-1,"homeName":"Heracles Almelo","awayName":"FC Utrecht","homeScore":1,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"233432713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1576868400,"status":-1,"homeName":"RKC Waalwijk","awayName":"FC Twente Enschede","homeScore":3,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"243432714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1576949400,"status":-1,"homeName":"SC Heerenveen","awayName":"Heracles Almelo","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"253432715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1576953900,"status":-1,"homeName":"Sparta Rotterdam","awayName":"AZ Alkmaar","homeScore":3,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"263432716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1576953900,"status":-1,"homeName":"PSV Eindhoven","awayName":"PEC Zwolle","homeScore":4,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"273432717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1576957500,"status":-1,"homeName":"Willem II","awayName":"Fortuna Sittard","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"283432718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1577013300,"status":-1,"homeName":"AFC Ajax","awayName":"ADO Den Haag","homeScore":6,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"293432719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1577021400,"status":-1,"homeName":"FC Utrecht","awayName":"Feyenoord","homeScore":1,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"204432711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1577021400,"status":-1,"homeName":"Groningen","awayName":"Emmen","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"214432712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1577029500,"status":-1,"homeName":"Vitesse Arnhem","awayName":"VVV Venlo","homeScore":3,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"224432713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1579368600,"status":-1,"homeName":"Fortuna Sittard","awayName":"Vitesse Arnhem","homeScore":1,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"208232713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1564768800,"status":-1,"homeName":"PEC Zwolle","awayName":"Willem II","homeScore":1,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"218232714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1564849800,"status":-1,"homeName":"Vitesse Arnhem","awayName":"AFC Ajax","homeScore":2,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"228232715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1564849800,"status":-1,"homeName":"Emmen","awayName":"Groningen","homeScore":0,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"238232716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1564857900,"status":-1,"homeName":"VVV Venlo","awayName":"RKC Waalwijk","homeScore":3,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"248232717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1564857900,"status":-1,"homeName":"FC Twente Enschede","awayName":"PSV Eindhoven","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"258232718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1564913700,"status":-1,"homeName":"Heracles Almelo","awayName":"SC Heerenveen","homeScore":0,"awayScore":4,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"378232710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1564921800,"status":-1,"homeName":"Feyenoord","awayName":"Sparta Rotterdam","homeScore":2,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"268232719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1564929900,"status":-1,"homeName":"ADO Den Haag","awayName":"FC Utrecht","homeScore":2,"awayScore":4,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"388232711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1564941600,"status":-1,"homeName":"AZ Alkmaar","awayName":"Fortuna Sittard","homeScore":4,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"398232712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1565373600,"status":-1,"homeName":"Sparta Rotterdam","awayName":"VVV Venlo","homeScore":4,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"209232714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1565454600,"status":-1,"homeName":"Groningen","awayName":"FC Twente Enschede","homeScore":1,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"219232715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1565459100,"status":-1,"homeName":"AFC Ajax","awayName":"Emmen","homeScore":5,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"239232717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1565462700,"status":-1,"homeName":"Willem II","awayName":"Vitesse Arnhem","homeScore":0,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"249232718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1565518500,"status":-1,"homeName":"Fortuna Sittard","awayName":"Heracles Almelo","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"259232719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1565526600,"status":-1,"homeName":"SC Heerenveen","awayName":"Feyenoord","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"369232710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1565526600,"status":-1,"homeName":"RKC Waalwijk","awayName":"AZ Alkmaar","homeScore":0,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"379232711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1565534700,"status":-1,"homeName":"FC Utrecht","awayName":"PEC Zwolle","homeScore":3,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"229232716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1565546400,"status":-1,"homeName":"PSV Eindhoven","awayName":"ADO Den Haag","homeScore":3,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"389232712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1565978400,"status":-1,"homeName":"Vitesse Arnhem","awayName":"PEC Zwolle","homeScore":3,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"399232713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1566059400,"status":-1,"homeName":"VVV Venlo","awayName":"AFC Ajax","homeScore":1,"awayScore":4,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"100332716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1566059400,"status":-1,"homeName":"ADO Den Haag","awayName":"Sparta Rotterdam","homeScore":1,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"120332718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1566067500,"status":-1,"homeName":"Emmen","awayName":"SC Heerenveen","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"130332719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1566123300,"status":-1,"homeName":"Fortuna Sittard","awayName":"Willem II","homeScore":2,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"250332711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1566131400,"status":-1,"homeName":"FC Twente Enschede","awayName":"RKC Waalwijk","homeScore":3,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"260332712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1566139500,"status":-1,"homeName":"AZ Alkmaar","awayName":"Groningen","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":true},{"matchId":"240332710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1566139500,"status":-1,"homeName":"Feyenoord","awayName":"FC Utrecht","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"110332717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1566151200,"status":-1,"homeName":"Heracles Almelo","awayName":"PSV Eindhoven","homeScore":0,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"270332713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1566664200,"status":-1,"homeName":"Willem II","awayName":"Emmen","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"290332715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1566668700,"status":-1,"homeName":"Heracles Almelo","awayName":"Vitesse Arnhem","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"101332717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1566672300,"status":-1,"homeName":"SC Heerenveen","awayName":"FC Twente Enschede","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"121332719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1566728100,"status":-1,"homeName":"RKC Waalwijk","awayName":"ADO Den Haag","homeScore":0,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"241332711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1566736200,"status":-1,"homeName":"FC Utrecht","awayName":"VVV Venlo","homeScore":1,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"231332710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1566744300,"status":-1,"homeName":"PEC Zwolle","awayName":"Sparta Rotterdam","homeScore":2,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"261332713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1567188000,"status":-1,"homeName":"Emmen","awayName":"PEC Zwolle","homeScore":1,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"271332714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1567269000,"status":-1,"homeName":"SC Heerenveen","awayName":"Fortuna Sittard","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"291332716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1567273500,"status":-1,"homeName":"Groningen","awayName":"Heracles Almelo","homeScore":1,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"102332718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1567277100,"status":-1,"homeName":"ADO Den Haag","awayName":"VVV Venlo","homeScore":1,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"112332719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1567332900,"status":-1,"homeName":"FC Twente Enschede","awayName":"FC Utrecht","homeScore":3,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"222332710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1567341000,"status":-1,"homeName":"Sparta Rotterdam","awayName":"AFC Ajax","homeScore":1,"awayScore":4,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"232332711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1567349100,"status":-1,"homeName":"Willem II","awayName":"Feyenoord","homeScore":0,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"242332712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1567349100,"status":-1,"homeName":"Vitesse Arnhem","awayName":"AZ Alkmaar","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"281332715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1567360800,"status":-1,"homeName":"RKC Waalwijk","awayName":"PSV Eindhoven","homeScore":1,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"292332717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1568478600,"status":-1,"homeName":"AFC Ajax","awayName":"SC Heerenveen","homeScore":4,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"252332713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1568478600,"status":-1,"homeName":"AZ Alkmaar","awayName":"Sparta Rotterdam","homeScore":5,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":true},{"matchId":"272332715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1568483100,"status":-1,"homeName":"VVV Venlo","awayName":"Groningen","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"282332716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1568486700,"status":-1,"homeName":"FC Utrecht","awayName":"Emmen","homeScore":3,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"262332714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1568486700,"status":-1,"homeName":"PSV Eindhoven","awayName":"Vitesse Arnhem","homeScore":5,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"103332719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1568542500,"status":-1,"homeName":"PEC Zwolle","awayName":"RKC Waalwijk","homeScore":6,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"213332710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1568550600,"status":-1,"homeName":"Feyenoord","awayName":"ADO Den Haag","homeScore":3,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"223332711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1568550600,"status":-1,"homeName":"Heracles Almelo","awayName":"Willem II","homeScore":4,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"233332712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1568558700,"status":-1,"homeName":"Fortuna Sittard","awayName":"FC Twente Enschede","homeScore":2,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"243332713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569002400,"status":-1,"homeName":"FC Twente Enschede","awayName":"Heracles Almelo","homeScore":2,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"253332714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569083400,"status":-1,"homeName":"Sparta Rotterdam","awayName":"RKC Waalwijk","homeScore":4,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"263332715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569087900,"status":-1,"homeName":"Willem II","awayName":"VVV Venlo","homeScore":1,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"273332716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569087900,"status":-1,"homeName":"Groningen","awayName":"PEC Zwolle","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"283332717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569091500,"status":-1,"homeName":"Vitesse Arnhem","awayName":"Fortuna Sittard","homeScore":4,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"214332711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569147300,"status":-1,"homeName":"SC Heerenveen","awayName":"FC Utrecht","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"224332712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569155400,"status":-1,"homeName":"Emmen","awayName":"Feyenoord","homeScore":3,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"293332718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569163500,"status":-1,"homeName":"ADO Den Haag","awayName":"AZ Alkmaar","homeScore":0,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"204332710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569163500,"status":-1,"homeName":"PSV Eindhoven","awayName":"AFC Ajax","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"111332718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569429000,"status":-1,"homeName":"PSV Eindhoven","awayName":"Groningen","homeScore":3,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"280332714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569437100,"status":-1,"homeName":"AFC Ajax","awayName":"Fortuna Sittard","homeScore":5,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"251332712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569520800,"status":-1,"homeName":"Feyenoord","awayName":"AZ Alkmaar","homeScore":0,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"215332712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569607200,"status":-1,"homeName":"Emmen","awayName":"ADO Den Haag","homeScore":3,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"234332713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569688200,"status":-1,"homeName":"VVV Venlo","awayName":"SC Heerenveen","homeScore":0,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"264332716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569692700,"status":-1,"homeName":"AFC Ajax","awayName":"Groningen","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"274332717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569696300,"status":-1,"homeName":"Fortuna Sittard","awayName":"Sparta Rotterdam","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"294332719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569752100,"status":-1,"homeName":"RKC Waalwijk","awayName":"Vitesse Arnhem","homeScore":1,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"205332711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569760200,"status":-1,"homeName":"FC Utrecht","awayName":"Willem II","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"254332715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569760200,"status":-1,"homeName":"PEC Zwolle","awayName":"PSV Eindhoven","homeScore":0,"awayScore":4,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"284332718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569768300,"status":-1,"homeName":"Feyenoord","awayName":"FC Twente Enschede","homeScore":5,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"244332714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1569768300,"status":-1,"homeName":"AZ Alkmaar","awayName":"Heracles Almelo","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"225332713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1570212000,"status":-1,"homeName":"Groningen","awayName":"RKC Waalwijk","homeScore":3,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"235332714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1570293000,"status":-1,"homeName":"Heracles Almelo","awayName":"Emmen","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"245332715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1570297500,"status":-1,"homeName":"Sparta Rotterdam","awayName":"FC Twente Enschede","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"395332710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1570297500,"status":-1,"homeName":"Vitesse Arnhem","awayName":"FC Utrecht","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"265332717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1570301100,"status":-1,"homeName":"SC Heerenveen","awayName":"PEC Zwolle","homeScore":1,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"275332718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1570356900,"status":-1,"homeName":"ADO Den Haag","awayName":"AFC Ajax","homeScore":0,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"285332719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1570365000,"status":-1,"homeName":"Fortuna Sittard","awayName":"Feyenoord","homeScore":4,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"206332712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1570373100,"status":-1,"homeName":"Willem II","awayName":"AZ Alkmaar","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"255332716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1570373100,"status":-1,"homeName":"PSV Eindhoven","awayName":"VVV Venlo","homeScore":4,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"226332714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1571502600,"status":-1,"homeName":"AZ Alkmaar","awayName":"SC Heerenveen","homeScore":2,"awayScore":4,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":true},{"matchId":"246332716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1571502600,"status":-1,"homeName":"RKC Waalwijk","awayName":"AFC Ajax","homeScore":1,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"256332717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1571507100,"status":-1,"homeName":"FC Twente Enschede","awayName":"Willem II","homeScore":0,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"236332715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1571510700,"status":-1,"homeName":"VVV Venlo","awayName":"Vitesse Arnhem","homeScore":0,"awayScore":4,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"216332713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1571510700,"status":-1,"homeName":"FC Utrecht","awayName":"PSV Eindhoven","homeScore":3,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"276332719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1571566500,"status":-1,"homeName":"PEC Zwolle","awayName":"ADO Den Haag","homeScore":3,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"386332710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1571574600,"status":-1,"homeName":"Emmen","awayName":"Fortuna Sittard","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"396332711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1571574600,"status":-1,"homeName":"Groningen","awayName":"Sparta Rotterdam","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"266332718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1571582700,"status":-1,"homeName":"Feyenoord","awayName":"Heracles Almelo","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"207332713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572026400,"status":-1,"homeName":"FC Twente Enschede","awayName":"Emmen","homeScore":4,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"217332714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572107400,"status":-1,"homeName":"Willem II","awayName":"RKC Waalwijk","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"227332715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572111900,"status":-1,"homeName":"Vitesse Arnhem","awayName":"ADO Den Haag","homeScore":0,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"237332716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572113700,"status":-1,"homeName":"Fortuna Sittard","awayName":"VVV Venlo","homeScore":4,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"247332717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572115500,"status":-1,"homeName":"Heracles Almelo","awayName":"PEC Zwolle","homeScore":4,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"257332718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572174900,"status":-1,"homeName":"SC Heerenveen","awayName":"Groningen","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"267332719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572183000,"status":-1,"homeName":"Sparta Rotterdam","awayName":"FC Utrecht","homeScore":1,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"377332710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572183000,"status":-1,"homeName":"PSV Eindhoven","awayName":"AZ Alkmaar","homeScore":0,"awayScore":4,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"387332711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572191100,"status":-1,"homeName":"AFC Ajax","awayName":"Feyenoord","homeScore":4,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"238332717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572634800,"status":-1,"homeName":"PEC Zwolle","awayName":"AFC Ajax","homeScore":2,"awayScore":4,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"208332714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572715800,"status":-1,"homeName":"RKC Waalwijk","awayName":"Heracles Almelo","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"397332712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572720300,"status":-1,"homeName":"Sparta Rotterdam","awayName":"PSV Eindhoven","homeScore":2,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"228332716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572723900,"status":-1,"homeName":"AZ Alkmaar","awayName":"FC Twente Enschede","homeScore":3,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":true},{"matchId":"248332718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572779700,"status":-1,"homeName":"Emmen","awayName":"Vitesse Arnhem","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"258332719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572787800,"status":-1,"homeName":"VVV Venlo","awayName":"Feyenoord","homeScore":0,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"378332711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572787800,"status":-1,"homeName":"Groningen","awayName":"Willem II","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"218332715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572787800,"status":-1,"homeName":"FC Utrecht","awayName":"Fortuna Sittard","homeScore":6,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"368332710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1572795900,"status":-1,"homeName":"ADO Den Haag","awayName":"SC Heerenveen","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"388332712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1573239600,"status":-1,"homeName":"Vitesse Arnhem","awayName":"Groningen","homeScore":1,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"398332713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1573320600,"status":-1,"homeName":"SC Heerenveen","awayName":"Sparta Rotterdam","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"219332716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1573325100,"status":-1,"homeName":"Fortuna Sittard","awayName":"ADO Den Haag","homeScore":1,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"229332717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1573328700,"status":-1,"homeName":"Heracles Almelo","awayName":"VVV Venlo","homeScore":6,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"359332710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1573384500,"status":-1,"homeName":"AFC Ajax","awayName":"FC Utrecht","homeScore":4,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"239332718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1573392600,"status":-1,"homeName":"FC Twente Enschede","awayName":"PEC Zwolle","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"209332715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1573392600,"status":-1,"homeName":"Willem II","awayName":"PSV Eindhoven","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"369332711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1573400700,"status":-1,"homeName":"Feyenoord","awayName":"RKC Waalwijk","homeScore":3,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"249332719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1573412400,"status":-1,"homeName":"AZ Alkmaar","awayName":"Emmen","homeScore":3,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":true},{"matchId":"234432714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1579373100,"status":-1,"homeName":"FC Twente Enschede","awayName":"Groningen","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"244432715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1579373100,"status":-1,"homeName":"Feyenoord","awayName":"SC Heerenveen","homeScore":3,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"254432716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1579287600,"status":-1,"homeName":"PEC Zwolle","awayName":"FC Utrecht","homeScore":3,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"264432717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1579376700,"status":-1,"homeName":"AZ Alkmaar","awayName":"Willem II","homeScore":1,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"274432718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1579432500,"status":-1,"homeName":"VVV Venlo","awayName":"PSV Eindhoven","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"284432719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1579440600,"status":-1,"homeName":"AFC Ajax","awayName":"Sparta Rotterdam","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"394432710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1579440600,"status":-1,"homeName":"Emmen","awayName":"Heracles Almelo","homeScore":1,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"205432712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1579448700,"status":-1,"homeName":"ADO Den Haag","awayName":"RKC Waalwijk","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"215432713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1579892400,"status":-1,"homeName":"FC Utrecht","awayName":"ADO Den Haag","homeScore":4,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"225432714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1579973400,"status":-1,"homeName":"SC Heerenveen","awayName":"AZ Alkmaar","homeScore":1,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"235432715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1579977900,"status":-1,"homeName":"RKC Waalwijk","awayName":"VVV Venlo","homeScore":1,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"245432716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1579977900,"status":-1,"homeName":"Heracles Almelo","awayName":"Feyenoord","homeScore":2,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"255432717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1579981500,"status":-1,"homeName":"Sparta Rotterdam","awayName":"Fortuna Sittard","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"265432718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1580037300,"status":-1,"homeName":"Vitesse Arnhem","awayName":"Emmen","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"275432719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1580045400,"status":-1,"homeName":"Groningen","awayName":"AFC Ajax","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"385432710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1580045400,"status":-1,"homeName":"Willem II","awayName":"PEC Zwolle","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"395432711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1580053500,"status":-1,"homeName":"PSV Eindhoven","awayName":"FC Twente Enschede","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"206432713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1580497200,"status":-1,"homeName":"AZ Alkmaar","awayName":"RKC Waalwijk","homeScore":4,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"216432714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1580578200,"status":-1,"homeName":"ADO Den Haag","awayName":"Vitesse Arnhem","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"226432715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1580582700,"status":-1,"homeName":"Feyenoord","awayName":"Emmen","homeScore":3,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"236432716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1580582700,"status":-1,"homeName":"FC Twente Enschede","awayName":"Sparta Rotterdam","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"246432717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1580586300,"status":-1,"homeName":"PEC Zwolle","awayName":"Groningen","homeScore":1,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"256432718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1580642100,"status":-1,"homeName":"Willem II","awayName":"Heracles Almelo","homeScore":1,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"266432719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1580650200,"status":-1,"homeName":"Fortuna Sittard","awayName":"SC Heerenveen","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"376432710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1580650200,"status":-1,"homeName":"VVV Venlo","awayName":"FC Utrecht","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"386432711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1580658300,"status":-1,"homeName":"AFC Ajax","awayName":"PSV Eindhoven","homeScore":1,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"396432712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581102000,"status":-1,"homeName":"Heracles Almelo","awayName":"Fortuna Sittard","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"207432714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581183000,"status":-1,"homeName":"Groningen","awayName":"Vitesse Arnhem","homeScore":1,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"217432715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581187500,"status":-1,"homeName":"PSV Eindhoven","awayName":"Willem II","homeScore":3,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"227432716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581187500,"status":-1,"homeName":"SC Heerenveen","awayName":"VVV Venlo","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"237432717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581191100,"status":-1,"homeName":"RKC Waalwijk","awayName":"PEC Zwolle","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"247432718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581246900,"status":-14,"homeName":"FC Utrecht","awayName":"AFC Ajax","homeScore":0,"awayScore":0,"explain":"Postponed due to adverse weather conditions","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"257432719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581450300,"status":-1,"homeName":"Sparta Rotterdam","awayName":"ADO Den Haag","homeScore":4,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"367432710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581255000,"status":-14,"homeName":"AZ Alkmaar","awayName":"Feyenoord","homeScore":0,"awayScore":0,"explain":"Postponed due to adverse weather conditions","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"377432711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581442200,"status":-1,"homeName":"Emmen","awayName":"FC Twente Enschede","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"387432712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581867900,"status":-1,"homeName":"Willem II","awayName":"FC Utrecht","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"397432713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581706800,"status":-1,"homeName":"VVV Venlo","awayName":"Heracles Almelo","homeScore":1,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"208432715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581787800,"status":-1,"homeName":"FC Twente Enschede","awayName":"AZ Alkmaar","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"218432716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581792300,"status":-1,"homeName":"ADO Den Haag","awayName":"PSV Eindhoven","homeScore":0,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"228432717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581795900,"status":-1,"homeName":"Fortuna Sittard","awayName":"Emmen","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"238432718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581851700,"status":-1,"homeName":"Vitesse Arnhem","awayName":"SC Heerenveen","homeScore":4,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"248432719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581859800,"status":-1,"homeName":"Sparta Rotterdam","awayName":"Groningen","homeScore":1,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"358432710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581859800,"status":-1,"homeName":"AFC Ajax","awayName":"RKC Waalwijk","homeScore":3,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"368432711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1581867900,"status":-1,"homeName":"PEC Zwolle","awayName":"Feyenoord","homeScore":3,"awayScore":4,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"378432712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"","matchTime":1582311600,"status":-1,"homeName":"RKC Waalwijk","awayName":"Sparta Rotterdam","homeScore":0,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"388432713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1582392600,"status":-1,"homeName":"Emmen","awayName":"Willem II","homeScore":4,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"398432714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1582464600,"status":-1,"homeName":"AZ Alkmaar","awayName":"PEC Zwolle","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"209432716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1582397100,"status":-1,"homeName":"Feyenoord","awayName":"Fortuna Sittard","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"219432717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1582400700,"status":-1,"homeName":"Groningen","awayName":"VVV Venlo","homeScore":0,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"229432718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1582456500,"status":-1,"homeName":"FC Utrecht","awayName":"FC Twente Enschede","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"239432719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1582464600,"status":-1,"homeName":"Vitesse Arnhem","awayName":"PSV Eindhoven","homeScore":1,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"349432710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1582397100,"status":-1,"homeName":"SC Heerenveen","awayName":"ADO Den Haag","homeScore":2,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"359432711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1582472700,"status":-1,"homeName":"Heracles Almelo","awayName":"AFC Ajax","homeScore":1,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"369432712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1582916400,"status":-1,"homeName":"Willem II","awayName":"Groningen","homeScore":3,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"379432713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1582997400,"status":-1,"homeName":"ADO Den Haag","awayName":"Heracles Almelo","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"389432714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1583001900,"status":-1,"homeName":"VVV Venlo","awayName":"Fortuna Sittard","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"399432715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1583001900,"status":-1,"homeName":"PEC Zwolle","awayName":"Vitesse Arnhem","homeScore":4,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"100532718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1583005500,"status":-1,"homeName":"FC Twente Enschede","awayName":"SC Heerenveen","homeScore":2,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"110532719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1583089200,"status":-1,"homeName":"AFC Ajax","awayName":"AZ Alkmaar","homeScore":0,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"220532710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1583069400,"status":-1,"homeName":"PSV Eindhoven","awayName":"Feyenoord","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"230532711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1583077500,"status":-1,"homeName":"Sparta Rotterdam","awayName":"Emmen","homeScore":5,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"240532712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1583061300,"status":-1,"homeName":"RKC Waalwijk","awayName":"FC Utrecht","homeScore":2,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"250532713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1583606700,"status":-1,"homeName":"Emmen","awayName":"VVV Venlo","homeScore":3,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"260532714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1583521200,"status":-1,"homeName":"Fortuna Sittard","awayName":"PEC Zwolle","homeScore":1,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"270532715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1583610300,"status":-1,"homeName":"SC Heerenveen","awayName":"AFC Ajax","homeScore":1,"awayScore":3,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"280532716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1583602200,"status":-1,"homeName":"AZ Alkmaar","awayName":"ADO Den Haag","homeScore":4,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"290532717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1583606700,"status":-1,"homeName":"Vitesse Arnhem","awayName":"FC Twente Enschede","homeScore":1,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"101532719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1583666100,"status":-1,"homeName":"FC Utrecht","awayName":"Sparta Rotterdam","homeScore":5,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"211532710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1583674200,"status":-1,"homeName":"Heracles Almelo","awayName":"RKC Waalwijk","homeScore":4,"awayScore":2,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"221532711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1583674200,"status":-1,"homeName":"Feyenoord","awayName":"Willem II","homeScore":2,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"231532712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1583682300,"status":-1,"homeName":"Groningen","awayName":"PSV Eindhoven","homeScore":0,"awayScore":1,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"241532713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584126000,"status":-14,"homeName":"ADO Den Haag","awayName":"Fortuna Sittard","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"251532714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584207000,"status":-14,"homeName":"Willem II","awayName":"SC Heerenveen","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"261532715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584279000,"status":-14,"homeName":"AFC Ajax","awayName":"FC Twente Enschede","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"271532716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584215100,"status":-14,"homeName":"FC Utrecht","awayName":"Vitesse Arnhem","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"281532717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584211500,"status":-14,"homeName":"PEC Zwolle","awayName":"Heracles Almelo","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"291532718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584270900,"status":-14,"homeName":"Sparta Rotterdam","awayName":"Feyenoord","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"202532710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584211500,"status":-14,"homeName":"PSV Eindhoven","awayName":"Emmen","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"212532711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584287100,"status":-14,"homeName":"VVV Venlo","awayName":"AZ Alkmaar","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"222532712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584279000,"status":-14,"homeName":"RKC Waalwijk","awayName":"Groningen","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"232532713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584730800,"status":-14,"homeName":"Heracles Almelo","awayName":"Sparta Rotterdam","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"242532714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584811800,"status":-14,"homeName":"FC Twente Enschede","awayName":"ADO Den Haag","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"252532715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584816300,"status":-14,"homeName":"PEC Zwolle","awayName":"VVV Venlo","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"262532716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584816300,"status":-14,"homeName":"Vitesse Arnhem","awayName":"Willem II","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"272532717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584819900,"status":-14,"homeName":"SC Heerenveen","awayName":"RKC Waalwijk","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"282532718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584875700,"status":-14,"homeName":"Fortuna Sittard","awayName":"PSV Eindhoven","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"292532719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584883800,"status":-14,"homeName":"Feyenoord","awayName":"AFC Ajax","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"203532711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584883800,"status":-14,"homeName":"Groningen","awayName":"AZ Alkmaar","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"213532712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1584891900,"status":-14,"homeName":"Emmen","awayName":"FC Utrecht","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"223532713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586017800,"status":-14,"homeName":"Sparta Rotterdam","awayName":"SC Heerenveen","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"233532714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586017800,"status":-14,"homeName":"VVV Venlo","awayName":"Willem II","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"243532715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586022300,"status":-14,"homeName":"PSV Eindhoven","awayName":"Heracles Almelo","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"253532716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586025900,"status":-14,"homeName":"FC Utrecht","awayName":"Groningen","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"263532717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586025900,"status":-14,"homeName":"AZ Alkmaar","awayName":"Vitesse Arnhem","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"273532718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586081700,"status":-14,"homeName":"RKC Waalwijk","awayName":"Feyenoord","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"283532719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586089800,"status":-14,"homeName":"ADO Den Haag","awayName":"Emmen","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"393532710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586089800,"status":-14,"homeName":"AFC Ajax","awayName":"PEC Zwolle","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"204532712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586097900,"status":-14,"homeName":"FC Twente Enschede","awayName":"Fortuna Sittard","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"214532713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586627100,"status":-10,"homeName":"Groningen","awayName":"SC Heerenveen","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"224532714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586622600,"status":-14,"homeName":"Vitesse Arnhem","awayName":"RKC Waalwijk","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"234532715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586627100,"status":-14,"homeName":"Feyenoord","awayName":"VVV Venlo","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"244532716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586627100,"status":-14,"homeName":"Heracles Almelo","awayName":"AZ Alkmaar","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"254532717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586630700,"status":-14,"homeName":"Willem II","awayName":"ADO Den Haag","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"264532718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586686500,"status":-14,"homeName":"Fortuna Sittard","awayName":"FC Utrecht","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"274532719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586694600,"status":-14,"homeName":"Emmen","awayName":"AFC Ajax","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"384532710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586694600,"status":-14,"homeName":"PEC Zwolle","awayName":"FC Twente Enschede","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"394532711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1586702700,"status":-14,"homeName":"PSV Eindhoven","awayName":"Sparta Rotterdam","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"205532713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587486600,"status":-14,"homeName":"AZ Alkmaar","awayName":"PSV Eindhoven","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"215532714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587494700,"status":-14,"homeName":"Sparta Rotterdam","awayName":"PEC Zwolle","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"225532715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587573000,"status":-14,"homeName":"RKC Waalwijk","awayName":"Willem II","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"235532716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587573000,"status":-14,"homeName":"ADO Den Haag","awayName":"Feyenoord","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"245532717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587577500,"status":-14,"homeName":"Groningen","awayName":"Fortuna Sittard","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"255532718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587581100,"status":-14,"homeName":"SC Heerenveen","awayName":"Emmen","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"265532719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587581100,"status":-14,"homeName":"FC Utrecht","awayName":"Heracles Almelo","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"375532710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587659400,"status":-14,"homeName":"FC Twente Enschede","awayName":"VVV Venlo","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"385532711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587667500,"status":-14,"homeName":"AFC Ajax","awayName":"Vitesse Arnhem","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"395532712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587832200,"status":-10,"homeName":"PSV Eindhoven","awayName":"FC Utrecht","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"206532714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587832200,"status":-10,"homeName":"Fortuna Sittard","awayName":"AZ Alkmaar","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"216532715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587836700,"status":-10,"homeName":"Emmen","awayName":"RKC Waalwijk","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"226532716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587840300,"status":-10,"homeName":"Feyenoord","awayName":"Groningen","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"236532717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587840300,"status":-10,"homeName":"PEC Zwolle","awayName":"SC Heerenveen","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"246532718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587896100,"status":-10,"homeName":"Heracles Almelo","awayName":"FC Twente Enschede","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"256532719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587904200,"status":-10,"homeName":"Willem II","awayName":"AFC Ajax","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"366532710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587904200,"status":-10,"homeName":"VVV Venlo","awayName":"ADO Den Haag","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"376532711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1587912300,"status":-10,"homeName":"Vitesse Arnhem","awayName":"Sparta Rotterdam","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"386532712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1588509000,"status":-10,"homeName":"SC Heerenveen","awayName":"PSV Eindhoven","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"396532713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1588509000,"status":-10,"homeName":"Sparta Rotterdam","awayName":"Willem II","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"207532715","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1588509000,"status":-10,"homeName":"AZ Alkmaar","awayName":"FC Utrecht","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"217532716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1588509000,"status":-10,"homeName":"RKC Waalwijk","awayName":"Fortuna Sittard","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"227532717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1588509000,"status":-10,"homeName":"PEC Zwolle","awayName":"Emmen","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"237532718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1588509000,"status":-10,"homeName":"AFC Ajax","awayName":"VVV Venlo","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"247532719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1588509000,"status":-10,"homeName":"Vitesse Arnhem","awayName":"Heracles Almelo","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"357532710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1588509000,"status":-10,"homeName":"Groningen","awayName":"ADO Den Haag","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"367532711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1588509000,"status":-10,"homeName":"FC Twente Enschede","awayName":"Feyenoord","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"377532712","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1589113800,"status":-10,"homeName":"FC Utrecht","awayName":"SC Heerenveen","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"387532713","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1589113800,"status":-10,"homeName":"Feyenoord","awayName":"Vitesse Arnhem","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"397532714","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1589113800,"status":-10,"homeName":"Willem II","awayName":"FC Twente Enschede","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"208532716","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1589113800,"status":-10,"homeName":"PSV Eindhoven","awayName":"RKC Waalwijk","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"218532717","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1589113800,"status":-10,"homeName":"Fortuna Sittard","awayName":"AFC Ajax","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"228532718","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1589113800,"status":-10,"homeName":"Heracles Almelo","awayName":"Groningen","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"238532719","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1589113800,"status":-10,"homeName":"VVV Venlo","awayName":"Sparta Rotterdam","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"348532710","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1589113800,"status":-10,"homeName":"ADO Den Haag","awayName":"PEC Zwolle","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false},{"matchId":"358532711","leagueId":"1617","leagueType":1,"leagueName":"Holland Eredivisie","leagueShortName":"HOL D1","leagueColor":"#FF6699","matchTime":1589113800,"status":-10,"homeName":"Emmen","awayName":"AZ Alkmaar","homeScore":0,"awayScore":0,"explain":"","extraExplain":{"kickOff":0,"minute":0,"homeScore":0,"awayScore":0,"extraTimeStatus":0,"extraHomeScore":0,"extraAwayScore":0,"penHomeScore":0,"penAwayScore":0,"twoRoundsHomeScore":0,"twoRoundsAwayScore":0,"winner":0},"neutral":false}]}

# 379332712
# 399332714
# 100432717
# 110432718
# 120432719
# 230432710
# 389332713
# 250432712
# 240432711
# 260432713
# 270432714
# 280432715
# 101432718
# 221432710
# 241432712
# 231432711
# 111432719
# 290432716
# 261432714
# 271432715
# 291432717
# 281432716
# 251432713
# 102432719
# 212432710
# 222432711
# 232432712
# 242432713
# 252432714
# 262432715
# 272432716
# 282432717
# 213432711
# 203432710
# 292432718
# 223432712
# 233432713
# 243432714
# 253432715
# 263432716
# 273432717
# 283432718
# 293432719
# 204432711
# 214432712
# 224432713
# 208232713
# 218232714
# 228232715
# 238232716
# 248232717
# 258232718
# 378232710
# 268232719
# 388232711
# 398232712
# 209232714
# 219232715
# 239232717
# 249232718
# 259232719
# 369232710
# 379232711
# 229232716
# 389232712
# 399232713
# 100332716
# 120332718
# 130332719
# 250332711
# 260332712
# 240332710
# 110332717
# 270332713
# 290332715
# 101332717
# 121332719
# 241332711
# 231332710
# 261332713
# 271332714
# 291332716
# 102332718
# 112332719
# 222332710
# 232332711
# 242332712
# 281332715
# 292332717
# 252332713
# 272332715
# 282332716
# 262332714
# 103332719
# 213332710
# 223332711
# 233332712
# 243332713
# 253332714
# 263332715
# 273332716
# 283332717
# 214332711
# 224332712
# 293332718
# 204332710
# 111332718
# 280332714
# 251332712
# 215332712
# 234332713
# 264332716
# 274332717
# 294332719
# 205332711
# 254332715
# 284332718
# 244332714
# 225332713
# 235332714
# 245332715
# 395332710
# 265332717
# 275332718
# 285332719
# 206332712
# 255332716
# 226332714
# 246332716
# 256332717
# 236332715
# 216332713
# 276332719
# 386332710
# 396332711
# 266332718
# 207332713
# 217332714
# 227332715
# 237332716
# 247332717
# 257332718
# 267332719
# 377332710
# 387332711
# 238332717
# 208332714
# 397332712
# 228332716
# 248332718
# 258332719
# 378332711
# 218332715
# 368332710
# 388332712
# 398332713
# 219332716
# 229332717
# 359332710
# 239332718
# 209332715
# 369332711
# 249332719
# 234432714
# 244432715
# 254432716
# 264432717
# 274432718
# 284432719
# 394432710
# 205432712
# 215432713
# 225432714
# 235432715
# 245432716
# 255432717
# 265432718
# 275432719
# 385432710
# 395432711
# 206432713
# 216432714
# 226432715
# 236432716
# 246432717
# 256432718
# 266432719
# 376432710
# 386432711
# 396432712
# 207432714
# 217432715
# 227432716
# 237432717
# 247432718
# 257432719
# 367432710
# 377432711
# 387432712
# 397432713
# 208432715
# 218432716
# 228432717
# 238432718
# 248432719
# 358432710
# 368432711
# 378432712
# 388432713
# 398432714
# 209432716
# 219432717
# 229432718
# 239432719
# 349432710
# 359432711
# 369432712
# 379432713
# 389432714
# 399432715
# 100532718
# 110532719
# 220532710
# 230532711
# 240532712
# 250532713
# 260532714
# 270532715
# 280532716
# 290532717
# 101532719
# 211532710
# 221532711
# 231532712
# 241532713
# 251532714
# 261532715
# 271532716
# 281532717
# 291532718
# 202532710
# 212532711
# 222532712
# 232532713
# 242532714
# 252532715
# 262532716
# 272532717
# 282532718
# 292532719
# 203532711
# 213532712
# 223532713
# 233532714
# 243532715
# 253532716
# 263532717
# 273532718
# 283532719
# 393532710
# 204532712
# 214532713
# 224532714
# 234532715
# 244532716
# 254532717
# 264532718
# 274532719
# 384532710
# 394532711
# 205532713
# 215532714
# 225532715
# 235532716
# 245532717
# 255532718
# 265532719
# 375532710
# 385532711
# 395532712
# 206532714
# 216532715
# 226532716
# 236532717
# 246532718
# 256532719
# 366532710
# 376532711
# 386532712
# 396532713
# 207532715
# 217532716
# 227532717
# 237532718
# 247532719
# 357532710
# 367532711
# 377532712
# 387532713
# 397532714
# 208532716
# 218532717
# 228532718
# 238532719
# 348532710
# 358532711
