# %%
#  Ocp-Apim-Subscription-Key: {92449a18356c45c2a179ad74eefe53cf} 
# https://api.sportsdata.io/v3/soccer/stats/json/BoxScore/23013?key=92449a18356c45c2a179ad74eefe53cf

# %%
import requests
import json

# %%
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# %%
# TOKEN = "?key=92449a18356c45c2a179ad74eefe53cf"
API_START = "https://api.sportsdata.io/v3/soccer/stats/json/"

# %%
WANTED = "BoxScore/23013"

# %%
URL = API_START + WANTED + TOKEN

# %%
response = requests.get(URL) 
print(response.status_code)
# Out:
# 200

# %%
# information = response.json()
# jprint(information[0]["AssistantReferee2"])

jprint(response.json())
# Out:
# [
#     {
#         "AdditionalAssistantReferee1": null,
#         "AdditionalAssistantReferee2": null,
#         "AssistantReferee1": {
#             "FirstName": "Bas",
#             "LastName": "van Dongen",
#             "Nationality": "Netherlands",
#             "RefereeId": 795,
#             "ShortName": "B. van Dongen"
#         },
#         "AssistantReferee2": {
#             "FirstName": "Erwin",
#             "LastName": "Zeinstra",
#             "Nationality": "Netherlands",
#             "RefereeId": 204,
#             "ShortName": "E. Zeinstra"
#         },
#         "AwayTeamCoach": {
#             "CoachId": 253,
#             "FirstName": "Erik",
#             "LastName": "ten Hag",
#             "Nationality": "Netherlands",
#             "ShortName": "E. ten Hag"
#         },
#         "Bookings": [
#             {
#                 "BookingId": 86416,
#                 "GameId": 23013,
#                 "GameMinute": 23,
#                 "GameMinuteExtra": null,
#                 "Name": "Mat\u00fa\u0161 Bero",
#                 "PlayerId": 90028184,
#                 "TeamId": 688,
#                 "Type": "Yellow Card"
#             },
#             {
#                 "BookingId": 86424,
#                 "GameId": 23013,
#                 "GameMinute": 71,
#                 "GameMinuteExtra": null,
#                 "Name": "Jo\u00ebl Veltman",
#                 "PlayerId": 90027409,
#                 "TeamId": 547,
#                 "Type": "Yellow Card"
#             },
#             {
#                 "BookingId": 86425,
#                 "GameId": 23013,
#                 "GameMinute": 73,
#                 "GameMinuteExtra": null,
#                 "Name": "Nicol\u00e1s Tagliafico",
#                 "PlayerId": 90030271,
#                 "TeamId": 547,
#                 "Type": "Yellow Card"
#             },
#             {
#                 "BookingId": 86426,
#                 "GameId": 23013,
#                 "GameMinute": 74,
#                 "GameMinuteExtra": null,
#                 "Name": "Daley Blind",
#                 "PlayerId": 90026536,
#                 "TeamId": 547,
#                 "Type": "Yellow Card"
#             },
#             {
#                 "BookingId": 86430,
#                 "GameId": 23013,
#                 "GameMinute": 82,
#                 "GameMinuteExtra": null,
#                 "Name": "Riechedly Bazoer",
#                 "PlayerId": 90027419,
#                 "TeamId": 688,
#                 "Type": "Yellow Card"
#             },
#             {
#                 "BookingId": 86432,
#                 "GameId": 23013,
#                 "GameMinute": 85,
#                 "GameMinuteExtra": null,
#                 "Name": "Riechedly Bazoer",
#                 "PlayerId": 90027419,
#                 "TeamId": 688,
#                 "Type": "Yellow Red Card"
#             }
#         ],
#         "FourthReferee": {
#             "FirstName": "Christiaan",
#             "LastName": "Bax",
#             "Nationality": "Netherlands",
#             "RefereeId": 796,
#             "ShortName": "C. Bax"
#         },
#         "Game": {
#             "Attendance": 18100,
#             "AwayTeamCountryCode": "NLD",
#             "AwayTeamFormation": null,
#             "AwayTeamId": 547,
#             "AwayTeamKey": "AJA",
#             "AwayTeamMoneyLine": null,
#             "AwayTeamName": "AFC Ajax",
#             "AwayTeamPointSpreadPayout": null,
#             "AwayTeamScore": 2,
#             "AwayTeamScoreExtraTime": null,
#             "AwayTeamScorePenalty": null,
#             "AwayTeamScorePeriod1": 1,
#             "AwayTeamScorePeriod2": 1,
#             "Clock": null,
#             "ClockDisplay": "",
#             "ClockExtra": null,
#             "DateTime": "2019-08-03T16:30:00",
#             "Day": "2019-08-03T00:00:00",
#             "DrawMoneyLine": null,
#             "GameId": 23013,
#             "GlobalAwayTeamId": 90000547,
#             "GlobalGameId": 90023013,
#             "GlobalHomeTeamId": 90000688,
#             "Group": null,
#             "HomeTeamCountryCode": "NLD",
#             "HomeTeamFormation": null,
#             "HomeTeamId": 688,
#             "HomeTeamKey": "VIT",
#             "HomeTeamMoneyLine": null,
#             "HomeTeamName": "SBV Vitesse",
#             "HomeTeamPointSpreadPayout": null,
#             "HomeTeamScore": 2,
#             "HomeTeamScoreExtraTime": null,
#             "HomeTeamScorePenalty": null,
#             "HomeTeamScorePeriod1": 1,
#             "HomeTeamScorePeriod2": 1,
#             "IsClosed": true,
#             "OverPayout": null,
#             "OverUnder": null,
#             "Period": "Regular",
#             "PlayoffAggregateScore": null,
#             "PointSpread": null,
#             "RoundId": 385,
#             "Season": 2020,
#             "SeasonType": 1,
#             "Status": "Final",
#             "UnderPayout": null,
#             "Updated": "2020-02-27T02:14:24",
#             "UpdatedUtc": "2020-02-27T07:14:24",
#             "VenueId": 174,
#             "VenueType": "Home Away",
#             "Week": 1,
#             "Winner": "Scrambled"
#         },
#         "Goals": [
#             {
#                 "AssistedByPlayerId1": 90034254,
#                 "AssistedByPlayerId2": null,
#                 "AssistedByPlayerName1": "Scrambled",
#                 "AssistedByPlayerName2": "Scrambled",
#                 "GameId": 23013,
#                 "GameMinute": 11,
#                 "GameMinuteExtra": null,
#                 "GoalId": 55998,
#                 "Name": "Mat\u00fa\u0161 Bero",
#                 "PlayerId": 90028184,
#                 "TeamId": 688,
#                 "Type": "Goal"
#             },
#             {
#                 "AssistedByPlayerId1": 90031586,
#                 "AssistedByPlayerId2": null,
#                 "AssistedByPlayerName1": "Scrambled",
#                 "AssistedByPlayerName2": "Scrambled",
#                 "GameId": 23013,
#                 "GameMinute": 26,
#                 "GameMinuteExtra": null,
#                 "GoalId": 55999,
#                 "Name": "Donny van de Beek",
#                 "PlayerId": 90027425,
#                 "TeamId": 547,
#                 "Type": "Goal"
#             },
#             {
#                 "AssistedByPlayerId1": 90055533,
#                 "AssistedByPlayerId2": null,
#                 "AssistedByPlayerName1": "Scrambled",
#                 "AssistedByPlayerName2": "Scrambled",
#                 "GameId": 23013,
#                 "GameMinute": 49,
#                 "GameMinuteExtra": null,
#                 "GoalId": 56001,
#                 "Name": "Riechedly Bazoer",
#                 "PlayerId": 90027419,
#                 "TeamId": 688,
#                 "Type": "Goal"
#             },
#             {
#                 "AssistedByPlayerId1": 90027425,
#                 "AssistedByPlayerId2": null,
#                 "AssistedByPlayerName1": "Scrambled",
#                 "AssistedByPlayerName2": "Scrambled",
#                 "GameId": 23013,
#                 "GameMinute": 66,
#                 "GameMinuteExtra": null,
#                 "GoalId": 56002,
#                 "Name": "Du\u0161an Tadi\u0107",
#                 "PlayerId": 90026630,
#                 "TeamId": 547,
#                 "Type": "Goal"
#             }
#         ],
#         "HomeTeamCoach": {
#             "CoachId": 120,
#             "FirstName": "Leonid Viktorovich",
#             "LastName": "Slutskii",
#             "Nationality": "Russia",
#             "ShortName": "L. Slutskii"
#         },
#         "Lineups": [
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871910,
#                 "Name": "Lisandro Mart\u00ednez",
#                 "PitchPositionHorizontal": 15,
#                 "PitchPositionVertical": 35,
#                 "PlayerId": 90046621,
#                 "Position": "D",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871911,
#                 "Name": "Hakim Ziyech",
#                 "PitchPositionHorizontal": 45,
#                 "PitchPositionVertical": 15,
#                 "PlayerId": 90031586,
#                 "Position": "M",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871912,
#                 "Name": "R\u0103zvan Marin",
#                 "PitchPositionHorizontal": 30,
#                 "PitchPositionVertical": 15,
#                 "PlayerId": 90041818,
#                 "Position": "M",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871913,
#                 "Name": "Donny van de Beek",
#                 "PitchPositionHorizontal": 30,
#                 "PitchPositionVertical": 30,
#                 "PlayerId": 90027425,
#                 "Position": "M",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871914,
#                 "Name": "Andr\u00e9 Onana",
#                 "PitchPositionHorizontal": 5,
#                 "PitchPositionVertical": 30,
#                 "PlayerId": 90027424,
#                 "Position": "GK",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871915,
#                 "Name": "Jo\u00ebl Veltman",
#                 "PitchPositionHorizontal": 15,
#                 "PitchPositionVertical": 10,
#                 "PlayerId": 90027409,
#                 "Position": "D",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871916,
#                 "Name": "Du\u0161an Tadi\u0107",
#                 "PitchPositionHorizontal": 45,
#                 "PitchPositionVertical": 45,
#                 "PlayerId": 90026630,
#                 "Position": "A",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871917,
#                 "Name": "Daley Blind",
#                 "PitchPositionHorizontal": 30,
#                 "PitchPositionVertical": 45,
#                 "PlayerId": 90026536,
#                 "Position": "D",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871918,
#                 "Name": "Nicol\u00e1s Tagliafico",
#                 "PitchPositionHorizontal": 15,
#                 "PitchPositionVertical": 50,
#                 "PlayerId": 90030271,
#                 "Position": "D",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871919,
#                 "Name": "Kasper Dolberg",
#                 "PitchPositionHorizontal": 45,
#                 "PitchPositionVertical": 30,
#                 "PlayerId": 90043983,
#                 "Position": "A",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871920,
#                 "Name": "Perr Schuurs",
#                 "PitchPositionHorizontal": 15,
#                 "PitchPositionVertical": 25,
#                 "PlayerId": 90056659,
#                 "Position": "D",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871921,
#                 "Name": "Max Clark",
#                 "PitchPositionHorizontal": 15,
#                 "PitchPositionVertical": 50,
#                 "PlayerId": 90055533,
#                 "Position": "D",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871922,
#                 "Name": "Riechedly Bazoer",
#                 "PitchPositionHorizontal": 30,
#                 "PitchPositionVertical": 35,
#                 "PlayerId": 90027419,
#                 "Position": "M",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871923,
#                 "Name": "Thulani Serero",
#                 "PitchPositionHorizontal": 30,
#                 "PitchPositionVertical": 25,
#                 "PlayerId": 90027422,
#                 "Position": "M",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871924,
#                 "Name": "Mat\u00fa\u0161 Bero",
#                 "PitchPositionHorizontal": 30,
#                 "PitchPositionVertical": 50,
#                 "PlayerId": 90028184,
#                 "Position": "M",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871925,
#                 "Name": "Remko Pasveer",
#                 "PitchPositionHorizontal": 5,
#                 "PitchPositionVertical": 30,
#                 "PlayerId": 90029170,
#                 "Position": "GK",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871926,
#                 "Name": "Tim Matav\u017e",
#                 "PitchPositionHorizontal": 45,
#                 "PitchPositionVertical": 20,
#                 "PlayerId": 90031278,
#                 "Position": "A",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871927,
#                 "Name": "Bryan Linssen",
#                 "PitchPositionHorizontal": 45,
#                 "PitchPositionVertical": 40,
#                 "PlayerId": 90031570,
#                 "Position": "A",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871928,
#                 "Name": "Vyacheslav Karavaev",
#                 "PitchPositionHorizontal": 15,
#                 "PitchPositionVertical": 10,
#                 "PlayerId": 90034254,
#                 "Position": "D",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871929,
#                 "Name": "Oussama Tannane",
#                 "PitchPositionHorizontal": 30,
#                 "PitchPositionVertical": 10,
#                 "PlayerId": 90032899,
#                 "Position": "A",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871930,
#                 "Name": "Armando Obispo",
#                 "PitchPositionHorizontal": 15,
#                 "PitchPositionVertical": 35,
#                 "PlayerId": 90052170,
#                 "Position": "D",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871931,
#                 "Name": "Danilho Doekhi",
#                 "PitchPositionHorizontal": 15,
#                 "PitchPositionVertical": 25,
#                 "PlayerId": 90031783,
#                 "Position": "D",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Starter"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871932,
#                 "Name": "Dani de Wit",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90027434,
#                 "Position": "M",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871933,
#                 "Name": "Jurgen Ekkelenkamp",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90062204,
#                 "Position": "M",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871934,
#                 "Name": "Klaas-Jan Huntelaar",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90027115,
#                 "Position": "A",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871935,
#                 "Name": "Quincy Promes",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90038927,
#                 "Position": "A",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871936,
#                 "Name": "Bruno Varela",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90047926,
#                 "Position": "GK",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871937,
#                 "Name": "David Neres",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90045097,
#                 "Position": "A",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871938,
#                 "Name": "Kjell Scherpen",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90065949,
#                 "Position": "GK",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871939,
#                 "Name": "Lisandro Magall\u00e1n",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90030799,
#                 "Position": "D",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871940,
#                 "Name": "Noussair Mazraoui",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90055850,
#                 "Position": "D",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871941,
#                 "Name": "Kik Pierie",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90045152,
#                 "Position": "D",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871942,
#                 "Name": "Lasse Sch\u00f6ne",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90027415,
#                 "Position": "M",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 547,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871943,
#                 "Name": "Navarone Foor",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90031704,
#                 "Position": "M",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871944,
#                 "Name": "Mukhtar Ali",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90046912,
#                 "Position": "M",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871945,
#                 "Name": "Jay-Roy Grot",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90031714,
#                 "Position": "A",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871946,
#                 "Name": "Oussama Darfalou",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90054627,
#                 "Position": "A",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871947,
#                 "Name": "Kostas Lamprou",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90031939,
#                 "Position": "GK",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871948,
#                 "Name": "Charly Musonda",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90029837,
#                 "Position": "M",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871949,
#                 "Name": "Tom\u00e1\u0161 H\u00e1jek",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90047139,
#                 "Position": "D",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871950,
#                 "Name": "Julian Lelieveld",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90031806,
#                 "Position": "D",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 871951,
#                 "Name": "Hillary Gong Chukwah",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90048209,
#                 "Position": "A",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 0,
#                 "GameMinuteExtra": null,
#                 "LineupId": 872004,
#                 "Name": "Thomas Buitink",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90057833,
#                 "Position": "A",
#                 "ReplacedPlayerId": null,
#                 "ReplacedPlayerName": null,
#                 "TeamId": 688,
#                 "Type": "Bench"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 61,
#                 "GameMinuteExtra": null,
#                 "LineupId": 872135,
#                 "Name": "Jay-Roy Grot",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90031714,
#                 "Position": "A",
#                 "ReplacedPlayerId": 90031278,
#                 "ReplacedPlayerName": "Tim Matav\u017e",
#                 "TeamId": 688,
#                 "Type": "Substitute In"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 66,
#                 "GameMinuteExtra": null,
#                 "LineupId": 872136,
#                 "Name": "Hillary Gong Chukwah",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90048209,
#                 "Position": "A",
#                 "ReplacedPlayerId": 90032899,
#                 "ReplacedPlayerName": "Oussama Tannane",
#                 "TeamId": 688,
#                 "Type": "Substitute In"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 69,
#                 "GameMinuteExtra": null,
#                 "LineupId": 872137,
#                 "Name": "Noussair Mazraoui",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90055850,
#                 "Position": "D",
#                 "ReplacedPlayerId": 90041818,
#                 "ReplacedPlayerName": "R\u0103zvan Marin",
#                 "TeamId": 547,
#                 "Type": "Substitute In"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 69,
#                 "GameMinuteExtra": null,
#                 "LineupId": 872138,
#                 "Name": "Quincy Promes",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90038927,
#                 "Position": "A",
#                 "ReplacedPlayerId": 90031586,
#                 "ReplacedPlayerName": "Hakim Ziyech",
#                 "TeamId": 547,
#                 "Type": "Substitute In"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 79,
#                 "GameMinuteExtra": null,
#                 "LineupId": 872143,
#                 "Name": "Charly Musonda",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90029837,
#                 "Position": "M",
#                 "ReplacedPlayerId": 90027422,
#                 "ReplacedPlayerName": "Thulani Serero",
#                 "TeamId": 688,
#                 "Type": "Substitute In"
#             },
#             {
#                 "GameId": 23013,
#                 "GameMinute": 82,
#                 "GameMinuteExtra": null,
#                 "LineupId": 872185,
#                 "Name": "David Neres",
#                 "PitchPositionHorizontal": null,
#                 "PitchPositionVertical": null,
#                 "PlayerId": 90045097,
#                 "Position": "A",
#                 "ReplacedPlayerId": 90043983,
#                 "ReplacedPlayerName": "Kasper Dolberg",
#                 "TeamId": 547,
#                 "Type": "Substitute In"
#             }
#         ],
#         "MainReferee": {
#             "FirstName": "Bas",
#             "LastName": "Nijhuis",
#             "Nationality": "Netherlands",
#             "RefereeId": 789,
#             "ShortName": "B. Nijhuis"
#         },
#         "PenaltyShootouts": [],
#         "PlayerGames": [
#             {
#                 "Assists": 0.0,
#                 "BlockedShots": 0.0,
#                 "Captain": false,
#                 "CornersWon": 0.0,
#                 "Crosses": 0.8,
#                 "DateTime": "2019-08-03T16:30:00",
#                 "Day": "2019-08-03T00:00:00",
#                 "DefenderCleanSheets": 0.0,
#                 "DraftKingsPosition": "Scrambled",
#                 "DraftKingsSalary": null,
#                 "FanDuelPosition": "Scrambled",
#                 "FanDuelSalary": null,
#                 "FantasyPoints": 2.9,
#                 "FantasyPointsDraftKings": 2.9,
#                 "FantasyPointsFanDuel": null,
#                 "FantasyPointsMondogoal": 4.0,
#                 "FantasyPointsYahoo": null,
#                 "Fouled": 0.8,
#                 "Fouls": 0.0,
#                 "GameId": 23013,
#                 "Games": 1,
#                 "GlobalGameId": 90023013,
#                 "GlobalOpponentId": 90000688,
#                 "GlobalTeamId": 90000547,
#                 "GoalkeeperCleanSheets": 0.0,
#                 "GoalkeeperGoalsAgainst": 0.0,
#                 "GoalkeeperSaves": 0.0,
#                 "GoalkeeperSingleGoalAgainst": 0.0,
#                 "GoalkeeperWins": 0.0,
#                 "Goals": 0.0,
#                 "HomeOrAway": "AWAY",
#                 "InjuryBodyPart": "Scrambled",
#                 "InjuryNotes": "Scrambled",
#                 "InjuryStartDate": null,
#                 "InjuryStatus": "Scrambled",
#                 "Interceptions": 1.6,
#                 "IsGameOver": true,
#                 "Jersey": 21,
#                 "LastManTackle": 0.0,
#                 "Minutes": 79.5,
#                 "MondogoalPosition": "Scrambled",
#                 "MondogoalSalary": null,
#                 "Name": "Lisandro Mart\u00ednez",
#                 "Offsides": 0.0,
#                 "Opponent": "SBV Vitesse",
#                 "OpponentId": 688,
#                 "OpponentScore": 1.6,
#                 "OwnGoals": 0.0,
#                 "Passes": 58.3,
#                 "PassesCompleted": 52.1,
#                 "PenaltiesConceded": 0.0,
#                 "PenaltiesWon": 0.0,
#                 "PenaltyKickGoals": 0.0,
#                 "PenaltyKickMisses": 0.0,
#                 "PenaltyKickSaves": 0.0,
#                 "PlayerId": 90046621,
#                 "Position": "D",
#                 "PositionCategory": "D",
#                 "RedCards": 0.0,
#                 "RoundId": 385,
#                 "Score": 1.6,
#                 "Season": 2020,
#                 "SeasonType": 1,
#                 "ShortName": "L. Mart\u00ednez",
#                 "Shots": 0.0,
#                 "ShotsOnGoal": 0.0,
#                 "Started": 1,
#                 "StatId": 1708501,
#                 "Suspension": false,
#                 "SuspensionReason": null,
#                 "TacklesWon": 0.8,
#                 "Team": "AFC Ajax",
#                 "TeamId": 547,
#                 "Touches": 0.0,
#                 "Updated": "2019-08-08T22:24:57",
#                 "UpdatedUtc": "2019-08-09T02:24:57",
#                 "YahooPosition": "Scrambled",
#                 "YahooSalary": null,
#                 "YellowCards": 0.0,
#                 "YellowRedCards": 0.0
#             },
#             {
#                 "Assists": 0.8,
#                 "BlockedShots": 0.8,
#                 "Captain": false,
#                 "CornersWon": 0.8,
#                 "Crosses": 3.9,
#                 "DateTime": "2019-08-03T16:30:00",
#                 "Day": "2019-08-03T00:00:00",
#                 "DefenderCleanSheets": 0.0,
#                 "DraftKingsPosition": "Scrambled",
#                 "DraftKingsSalary": null,
#                 "FanDuelPosition": "Scrambled",
#                 "FanDuelSalary": null,
#                 "FantasyPoints": 16.6,
#                 "FantasyPointsDraftKings": 16.6,
#                 "FantasyPointsFanDuel": null,
#                 "FantasyPointsMondogoal": 7.9,
#                 "FantasyPointsYahoo": null,
#                 "Fouled": 0.8,
#                 "Fouls": 0.0,
#                 "GameId": 23013,
#                 "Games": 1,
#                 "GlobalGameId": 90023013,
#                 "GlobalOpponentId": 90000688,
#                 "GlobalTeamId": 90000547,
#                 "GoalkeeperCleanSheets": 0.0,
#                 "GoalkeeperGoalsAgainst": 0.0,
#                 "GoalkeeperSaves": 0.0,
#                 "GoalkeeperSingleGoalAgainst": 0.0,
#                 "GoalkeeperWins": 0.0,
#                 "Goals": 0.0,
#                 "HomeOrAway": "AWAY",
#                 "InjuryBodyPart": "Scrambled",
#                 "InjuryNotes": "Scrambled",
#                 "InjuryStartDate": null,
#                 "InjuryStatus": "Scrambled",
#                 "Interceptions": 0.0,
#                 "IsGameOver": true,
#                 "Jersey": 22,
#                 "LastManTackle": 0.0,
#                 "Minutes": 60.9,
#                 "MondogoalPosition": "Scrambled",
#                 "MondogoalSalary": null,
#                 "Name": "Hakim Ziyech",
#                 "Offsides": 0.0,
#                 "Opponent": "SBV Vitesse",
#                 "OpponentId": 688,
#                 "OpponentScore": 1.6,
#                 "OwnGoals": 0.0,
#                 "Passes": 56.5,
#                 "PassesCompleted": 39.7,
#                 "PenaltiesConceded": 0.0,
#                 "PenaltiesWon": 0.0,
#                 "PenaltyKickGoals": 0.0,
#                 "PenaltyKickMisses": 0.0,
#                 "PenaltyKickSaves": 0.0,
#                 "PlayerId": 90031586,
#                 "Position": "M",
#                 "PositionCategory": "M",
#                 "RedCards": 0.0,
#                 "RoundId": 385,
#                 "Score": 1.6,
#                 "Season": 2020,
#                 "SeasonType": 1,
#                 "ShortName": "H. Ziyech",
#                 "Shots": 3.1,
#                 "ShotsOnGoal": 0.8,
#                 "Started": 1,
#                 "StatId": 1708502,
#                 "Suspension": false,
#                 "SuspensionReason": null,
#                 "TacklesWon": 2.3,
#                 "Team": "AFC Ajax",
#                 "TeamId": 547,
#                 "Touches": 0.0,
#                 "Updated": "2019-08-08T22:24:57",
#                 "UpdatedUtc": "2019-08-09T02:24:57",
#                 "YahooPosition": "Scrambled",
#                 "YahooSalary": null,
#                 "YellowCards": 0.0,
#                 "YellowRedCards": 0.0
#             },
#             {
#                 "Assists": 0.0,
#                 "BlockedShots": 0.0,
#                 "Captain": false,
#                 "CornersWon": 0.0,
#                 "Crosses": 2.3,
#                 "DateTime": "2019-08-03T16:30:00",
#                 "Day": "2019-08-03T00:00:00",
#                 "DefenderCleanSheets": 0.0,
#                 "DraftKingsPosition": "Scrambled",
#                 "DraftKingsSalary": null,
#                 "FanDuelPosition": "Scrambled",
#                 "FanDuelSalary": null,
#                 "FantasyPoints": 4.5,
#                 "FantasyPointsDraftKings": 4.5,
#                 "FantasyPointsFanDuel": null,
#                 "FantasyPointsMondogoal": 2.1,
#                 "FantasyPointsYahoo": null,
#                 "Fouled": 0.0,
#                 "Fouls": 2.3,
#                 "GameId": 23013,
#                 "Games": 1,
#                 "GlobalGameId": 90023013,
#                 "GlobalOpponentId": 90000688,
#                 "GlobalTeamId": 90000547,
#                 "GoalkeeperCleanSheets": 0.0,
#                 "GoalkeeperGoalsAgainst": 0.0,
#                 "GoalkeeperSaves": 0.0,
#                 "GoalkeeperSingleGoalAgainst": 0.0,
#                 "GoalkeeperWins": 0.0,
#                 "Goals": 0.0,
#                 "HomeOrAway": "AWAY",
#                 "InjuryBodyPart": "Scrambled",
#                 "InjuryNotes": "Scrambled",
#                 "InjuryStartDate": null,
#                 "InjuryStatus": "Scrambled",
#                 "Interceptions": 0.0,
#                 "IsGameOver": true,
#                 "Jersey": 18,
#                 "LastManTackle": 0.0,
#                 "Minutes": 60.9,
#                 "MondogoalPosition": "Scrambled",
#                 "MondogoalSalary": null,
#                 "Name": "R\u0103zvan Marin",
#                 "Offsides": 0.0,
#                 "Opponent": "SBV Vitesse",
#                 "OpponentId": 688,
#                 "OpponentScore": 1.6,
#                 "OwnGoals": 0.0,
#                 "Passes": 58.3,
#                 "PassesCompleted": 50.3,
#                 "PenaltiesConceded": 0.0,
#                 "PenaltiesWon": 0.0,
#                 "PenaltyKickGoals": 0.0,
#                 "PenaltyKickMisses": 0.0,
#                 "PenaltyKickSaves": 0.0,
#                 "PlayerId": 90041818,
#                 "Position": "M",
#                 "PositionCategory": "M",
#                 "RedCards": 0.0,
#                 "RoundId": 385,
#                 "Score": 1.6,
#                 "Season": 2020,
#                 "SeasonType": 1,
#                 "ShortName": "R. Marin",
#                 "Shots": 2.3,
#                 "ShotsOnGoal": 0.0,
#                 "Started": 1,
#                 "StatId": 1708503,
#                 "Suspension": false,
#                 "SuspensionReason": null,
#                 "TacklesWon": 1.6,
#                 "Team": "AFC Ajax",
#                 "TeamId": 547,
#                 "Touches": 0.0,
#                 "Updated": "2019-08-08T22:24:57",
#                 "UpdatedUtc": "2019-08-09T02:24:57",
#                 "YahooPosition": "Scrambled",
#                 "YahooSalary": null,
#                 "YellowCards": 0.0,
#                 "YellowRedCards": 0.0
#             },
#             {
#                 "Assists": 0.8,
#                 "BlockedShots": 0.0,
#                 "Captain": false,
#                 "CornersWon": 2.3,
#                 "Crosses": 0.0,
#                 "DateTime": "2019-08-03T16:30:00",
#                 "Day": "2019-08-03T00:00:00",
#                 "DefenderCleanSheets": 0.0,
#                 "DraftKingsPosition": "Scrambled",
#                 "DraftKingsSalary": null,
#                 "FanDuelPosition": "Scrambled",
#                 "FanDuelSalary": null,
#                 "FantasyPoints": 23.0,
#                 "FantasyPointsDraftKings": 23.0,
#                 "FantasyPointsFanDuel": null,
#                 "FantasyPointsMondogoal": 19.5,
#                 "FantasyPointsYahoo": null,
#                 "Fouled": 0.8,
#                 "Fouls": 1.6,
#                 "GameId": 23013,
#                 "Games": 1,
#                 "GlobalGameId": 90023013,
#                 "GlobalOpponentId": 90000688,
#                 "GlobalTeamId": 90000547,
#                 "GoalkeeperCleanSheets": 0.0,
#                 "GoalkeeperGoalsAgainst": 0.0,
#                 "GoalkeeperSaves": 0.0,
#                 "GoalkeeperSingleGoalAgainst": 0.0,
#                 "GoalkeeperWins": 0.0,
#                 "Goals": 0.8,
#                 "HomeOrAway": "AWAY",
#                 "InjuryBodyPart": "Scrambled",
#                 "InjuryNotes": "Scrambled",
#                 "InjuryStartDate": null,
#                 "InjuryStatus": "Scrambled",
#                 "Interceptions": 0.0,
#                 "IsGameOver": true,
#                 "Jersey": 6,
#                 "LastManTackle": 0.0,
#                 "Minutes": 79.5,
#                 "MondogoalPosition": "Scrambled",
#                 "MondogoalSalary": null,
#                 "Name": "Donny van de Beek",
#                 "Offsides": 0.8,
#                 "Opponent": "SBV Vitesse",
#                 "OpponentId": 688,
#                 "OpponentScore": 1.6,
#                 "OwnGoals": 0.0,
#                 "Passes": 39.7,
#                 "PassesCompleted": 30.9,
#                 "PenaltiesConceded": 0.0,
#                 "PenaltiesWon": 0.0,
#                 "PenaltyKickGoals": 0.0,
#                 "PenaltyKickMisses": 0.0,
#                 "PenaltyKickSaves": 0.0,
#                 "PlayerId": 90027425,
#                 "Position": "M",
#                 "PositionCategory": "M",
#                 "RedCards": 0.0,
#                 "RoundId": 385,
#                 "Score": 1.6,
#                 "Season": 2020,
#                 "SeasonType": 1,
#                 "ShortName": "D. van de Beek",
#                 "Shots": 3.9,
#                 "ShotsOnGoal": 3.1,
#                 "Started": 1,
#                 "StatId": 1708504,
#                 "Suspension": false,
#                 "SuspensionReason": null,
#                 "TacklesWon": 0.8,
#                 "Team": "AFC Ajax",
#                 "TeamId": 547,
#                 "Touches": 0.0,
#                 "Updated": "2019-08-08T22:24:57",
#                 "UpdatedUtc": "2019-08-09T02:24:57",
#                 "YahooPosition": "Scrambled",
#                 "YahooSalary": null,
#                 "YellowCards": 0.0,
#                 "YellowRedCards": 0.0
#             },
#             {
#                 "Assists": 0.0,
#                 "BlockedShots": 0.0,
#                 "Captain": false,
#                 "CornersWon": 0.0,
#                 "Crosses": 0.0,
#                 "DateTime": "2019-08-03T16:30:00",
#                 "Day": "2019-08-03T00:00:00",
#                 "DefenderCleanSheets": 0.0,
#                 "DraftKingsPosition": "Scrambled",
#                 "DraftKingsSalary": null,
#                 "FanDuelPosition": "Scrambled",
#                 "FanDuelSalary": null,
#                 "FantasyPoints": -1.8,
#                 "FantasyPointsDraftKings": -1.8,
#                 "FantasyPointsFanDuel": null,
#                 "FantasyPointsMondogoal": -1.1,
#                 "FantasyPointsYahoo": null,
#                 "Fouled": 0.0,
#                 "Fouls": 0.0,
#                 "GameId": 23013,
#                 "Games": 1,
#                 "GlobalGameId": 90023013,
#                 "GlobalOpponentId": 90000688,
#                 "GlobalTeamId": 90000547,
#                 "GoalkeeperCleanSheets": 0.0,
#                 "GoalkeeperGoalsAgainst": 1.6,
#                 "GoalkeeperSaves": 0.8,
#                 "GoalkeeperSingleGoalAgainst": 0.0,
#                 "GoalkeeperWins": 0.0,
#                 "Goals": 0.0,
#                 "HomeOrAway": "AWAY",
#                 "InjuryBodyPart": "Scrambled",
#                 "InjuryNotes": "Scrambled",
#                 "InjuryStartDate": null,
#                 "InjuryStatus": "Scrambled",
#                 "Interceptions": 0.0,
#                 "IsGameOver": true,
#                 "Jersey": 24,
#                 "LastManTackle": 0.0,
#                 "Minutes": 79.5,
#                 "MondogoalPosition": "Scrambled",
# ...
#                 "InjuryStartDate": null,
#                 "InjuryStatus": "Scrambled",
#                 "Interceptions": 0.8,
#                 "IsGameOver": true,
#                 "Jersey": 19,
#                 "LastManTackle": 0.0,
#                 "Minutes": 21.2,
#                 "MondogoalPosition": "Scrambled",
#                 "MondogoalSalary": null,
#                 "Name": "Hillary Gong Chukwah",
#                 "Offsides": 0.0,
#                 "Opponent": "AFC Ajax",
#                 "OpponentId": 547,
#                 "OpponentScore": 1.6,
#                 "OwnGoals": 0.0,
#                 "Passes": 2.3,
#                 "PassesCompleted": 1.6,
#                 "PenaltiesConceded": 0.0,
#                 "PenaltiesWon": 0.0,
#                 "PenaltyKickGoals": 0.0,
#                 "PenaltyKickMisses": 0.0,
#                 "PenaltyKickSaves": 0.0,
#                 "PlayerId": 90048209,
#                 "Position": "A",
#                 "PositionCategory": "A",
#                 "RedCards": 0.0,
#                 "RoundId": 385,
#                 "Score": 1.6,
#                 "Season": 2020,
#                 "SeasonType": 1,
#                 "ShortName": "H. Gong",
#                 "Shots": 0.8,
#                 "ShotsOnGoal": 0.0,
#                 "Started": 0,
#                 "StatId": 1708540,
#                 "Suspension": false,
#                 "SuspensionReason": null,
#                 "TacklesWon": 0.0,
#                 "Team": "SBV Vitesse",
#                 "TeamId": 688,
#                 "Touches": 0.0,
#                 "Updated": "2019-08-08T22:24:57",
#                 "UpdatedUtc": "2019-08-09T02:24:57",
#                 "YahooPosition": "Scrambled",
#                 "YahooSalary": null,
#                 "YellowCards": 0.0,
#                 "YellowRedCards": 0.0
#             },
#             {
#                 "Assists": 0.0,
#                 "BlockedShots": 0.0,
#                 "Captain": false,
#                 "CornersWon": 0.0,
#                 "Crosses": 0.0,
#                 "DateTime": "2019-08-03T16:30:00",
#                 "Day": "2019-08-03T00:00:00",
#                 "DefenderCleanSheets": 0.0,
#                 "DraftKingsPosition": "Scrambled",
#                 "DraftKingsSalary": null,
#                 "FanDuelPosition": "Scrambled",
#                 "FanDuelSalary": null,
#                 "FantasyPoints": 0.0,
#                 "FantasyPointsDraftKings": 0.0,
#                 "FantasyPointsFanDuel": null,
#                 "FantasyPointsMondogoal": 0.0,
#                 "FantasyPointsYahoo": null,
#                 "Fouled": 0.0,
#                 "Fouls": 0.0,
#                 "GameId": 23013,
#                 "Games": 0,
#                 "GlobalGameId": 90023013,
#                 "GlobalOpponentId": 90000547,
#                 "GlobalTeamId": 90000688,
#                 "GoalkeeperCleanSheets": 0.0,
#                 "GoalkeeperGoalsAgainst": 0.0,
#                 "GoalkeeperSaves": 0.0,
#                 "GoalkeeperSingleGoalAgainst": 0.0,
#                 "GoalkeeperWins": 0.0,
#                 "Goals": 0.0,
#                 "HomeOrAway": "HOME",
#                 "InjuryBodyPart": "Scrambled",
#                 "InjuryNotes": "Scrambled",
#                 "InjuryStartDate": null,
#                 "InjuryStatus": "Scrambled",
#                 "Interceptions": 0.0,
#                 "IsGameOver": true,
#                 "Jersey": 2,
#                 "LastManTackle": 0.0,
#                 "Minutes": 0.0,
#                 "MondogoalPosition": "Scrambled",
#                 "MondogoalSalary": null,
#                 "Name": "Julian Lelieveld",
#                 "Offsides": 0.0,
#                 "Opponent": "AFC Ajax",
#                 "OpponentId": 547,
#                 "OpponentScore": 1.6,
#                 "OwnGoals": 0.0,
#                 "Passes": 0.0,
#                 "PassesCompleted": 0.0,
#                 "PenaltiesConceded": 0.0,
#                 "PenaltiesWon": 0.0,
#                 "PenaltyKickGoals": 0.0,
#                 "PenaltyKickMisses": 0.0,
#                 "PenaltyKickSaves": 0.0,
#                 "PlayerId": 90031806,
#                 "Position": "D",
#                 "PositionCategory": "D",
#                 "RedCards": 0.0,
#                 "RoundId": 385,
#                 "Score": 1.6,
#                 "Season": 2020,
#                 "SeasonType": 1,
#                 "ShortName": "J. Lelieveld",
#                 "Shots": 0.0,
#                 "ShotsOnGoal": 0.0,
#                 "Started": 0,
#                 "StatId": 1708541,
#                 "Suspension": false,
#                 "SuspensionReason": null,
#                 "TacklesWon": 0.0,
#                 "Team": "SBV Vitesse",
#                 "TeamId": 688,
#                 "Touches": 0.0,
#                 "Updated": "2019-08-08T22:24:57",
#                 "UpdatedUtc": "2019-08-09T02:24:57",
#                 "YahooPosition": "Scrambled",
#                 "YahooSalary": null,
#                 "YellowCards": 0.0,
#                 "YellowRedCards": 0.0
#             },
#             {
#                 "Assists": 0.0,
#                 "BlockedShots": 0.0,
#                 "Captain": false,
#                 "CornersWon": 0.0,
#                 "Crosses": 0.0,
#                 "DateTime": "2019-08-03T16:30:00",
#                 "Day": "2019-08-03T00:00:00",
#                 "DefenderCleanSheets": 0.0,
#                 "DraftKingsPosition": "Scrambled",
#                 "DraftKingsSalary": null,
#                 "FanDuelPosition": "Scrambled",
#                 "FanDuelSalary": null,
#                 "FantasyPoints": -0.4,
#                 "FantasyPointsDraftKings": -0.4,
#                 "FantasyPointsFanDuel": null,
#                 "FantasyPointsMondogoal": -0.2,
#                 "FantasyPointsYahoo": null,
#                 "Fouled": 0.0,
#                 "Fouls": 0.8,
#                 "GameId": 23013,
#                 "Games": 1,
#                 "GlobalGameId": 90023013,
#                 "GlobalOpponentId": 90000547,
#                 "GlobalTeamId": 90000688,
#                 "GoalkeeperCleanSheets": 0.0,
#                 "GoalkeeperGoalsAgainst": 0.0,
#                 "GoalkeeperSaves": 0.0,
#                 "GoalkeeperSingleGoalAgainst": 0.0,
#                 "GoalkeeperWins": 0.0,
#                 "Goals": 0.0,
#                 "HomeOrAway": "HOME",
#                 "InjuryBodyPart": "Scrambled",
#                 "InjuryNotes": "Scrambled",
#                 "InjuryStartDate": null,
#                 "InjuryStatus": "Scrambled",
#                 "Interceptions": 0.0,
#                 "IsGameOver": true,
#                 "Jersey": 27,
#                 "LastManTackle": 0.0,
#                 "Minutes": 8.6,
#                 "MondogoalPosition": "Scrambled",
#                 "MondogoalSalary": null,
#                 "Name": "Charly Musonda",
#                 "Offsides": 0.0,
#                 "Opponent": "AFC Ajax",
#                 "OpponentId": 547,
#                 "OpponentScore": 1.6,
#                 "OwnGoals": 0.0,
#                 "Passes": 1.6,
#                 "PassesCompleted": 1.6,
#                 "PenaltiesConceded": 0.0,
#                 "PenaltiesWon": 0.0,
#                 "PenaltyKickGoals": 0.0,
#                 "PenaltyKickMisses": 0.0,
#                 "PenaltyKickSaves": 0.0,
#                 "PlayerId": 90029837,
#                 "Position": "M",
#                 "PositionCategory": "M",
#                 "RedCards": 0.0,
#                 "RoundId": 385,
#                 "Score": 1.6,
#                 "Season": 2020,
#                 "SeasonType": 1,
#                 "ShortName": "C. Musonda",
#                 "Shots": 0.0,
#                 "ShotsOnGoal": 0.0,
#                 "Started": 0,
#                 "StatId": 1708586,
#                 "Suspension": false,
#                 "SuspensionReason": null,
#                 "TacklesWon": 0.0,
#                 "Team": "SBV Vitesse",
#                 "TeamId": 688,
#                 "Touches": 0.0,
#                 "Updated": "2019-08-08T22:24:57",
#                 "UpdatedUtc": "2019-08-09T02:24:57",
#                 "YahooPosition": "Scrambled",
#                 "YahooSalary": null,
#                 "YellowCards": 0.0,
#                 "YellowRedCards": 0.0
#             },
#             {
#                 "Assists": 0.0,
#                 "BlockedShots": 0.0,
#                 "Captain": false,
#                 "CornersWon": 0.0,
#                 "Crosses": 0.0,
#                 "DateTime": "2019-08-03T16:30:00",
#                 "Day": "2019-08-03T00:00:00",
#                 "DefenderCleanSheets": 0.0,
#                 "DraftKingsPosition": "Scrambled",
#                 "DraftKingsSalary": null,
#                 "FanDuelPosition": "Scrambled",
#                 "FanDuelSalary": null,
#                 "FantasyPoints": 0.0,
#                 "FantasyPointsDraftKings": 0.0,
#                 "FantasyPointsFanDuel": null,
#                 "FantasyPointsMondogoal": 0.0,
#                 "FantasyPointsYahoo": null,
#                 "Fouled": 0.0,
#                 "Fouls": 0.0,
#                 "GameId": 23013,
#                 "Games": 0,
#                 "GlobalGameId": 90023013,
#                 "GlobalOpponentId": 90000547,
#                 "GlobalTeamId": 90000688,
#                 "GoalkeeperCleanSheets": 0.0,
#                 "GoalkeeperGoalsAgainst": 0.0,
#                 "GoalkeeperSaves": 0.0,
#                 "GoalkeeperSingleGoalAgainst": 0.0,
#                 "GoalkeeperWins": 0.0,
#                 "Goals": 0.0,
#                 "HomeOrAway": "HOME",
#                 "InjuryBodyPart": "Scrambled",
#                 "InjuryNotes": "Scrambled",
#                 "InjuryStartDate": null,
#                 "InjuryStatus": "Scrambled",
#                 "Interceptions": 0.0,
#                 "IsGameOver": true,
#                 "Jersey": 18,
#                 "LastManTackle": 0.0,
#                 "Minutes": 0.0,
#                 "MondogoalPosition": "Scrambled",
#                 "MondogoalSalary": null,
#                 "Name": "Tom\u00e1\u0161 H\u00e1jek",
#                 "Offsides": 0.0,
#                 "Opponent": "AFC Ajax",
#                 "OpponentId": 547,
#                 "OpponentScore": 1.6,
#                 "OwnGoals": 0.0,
#                 "Passes": 0.0,
#                 "PassesCompleted": 0.0,
#                 "PenaltiesConceded": 0.0,
#                 "PenaltiesWon": 0.0,
#                 "PenaltyKickGoals": 0.0,
#                 "PenaltyKickMisses": 0.0,
#                 "PenaltyKickSaves": 0.0,
#                 "PlayerId": 90047139,
#                 "Position": "D",
#                 "PositionCategory": "D",
#                 "RedCards": 0.0,
#                 "RoundId": 385,
#                 "Score": 1.6,
#                 "Season": 2020,
#                 "SeasonType": 1,
#                 "ShortName": "T. H\u00e1jek",
#                 "Shots": 0.0,
#                 "ShotsOnGoal": 0.0,
#                 "Started": 0,
#                 "StatId": 1708587,
#                 "Suspension": false,
#                 "SuspensionReason": null,
#                 "TacklesWon": 0.0,
#                 "Team": "SBV Vitesse",
#                 "TeamId": 688,
#                 "Touches": 0.0,
#                 "Updated": "2019-08-08T22:24:57",
#                 "UpdatedUtc": "2019-08-09T02:24:57",
#                 "YahooPosition": "Scrambled",
#                 "YahooSalary": null,
#                 "YellowCards": 0.0,
#                 "YellowRedCards": 0.0
#             }
#         ],
#         "TeamGames": [
#             {
#                 "Assists": 1.6,
#                 "BlockedShots": 4.7,
#                 "CornersWon": 7.0,
#                 "Crosses": 15.0,
#                 "DateTime": "2019-08-03T16:30:00",
#                 "Day": "2019-08-03T00:00:00",
#                 "DefenderCleanSheets": 0.0,
#                 "FantasyPoints": 86.8,
#                 "FantasyPointsDraftKings": 86.8,
#                 "FantasyPointsFanDuel": null,
#                 "FantasyPointsMondogoal": 13.1,
#                 "FantasyPointsYahoo": null,
#                 "Fouled": 13.2,
#                 "Fouls": 11.5,
#                 "GameId": 23013,
#                 "Games": 1,
#                 "GlobalGameId": 90023013,
#                 "GlobalOpponentId": 90000688,
#                 "GlobalTeamId": 90000547,
#                 "GoalkeeperCleanSheets": 0.0,
#                 "GoalkeeperGoalsAgainst": 1.6,
#                 "GoalkeeperSaves": 0.8,
#                 "GoalkeeperSingleGoalAgainst": 0.0,
#                 "GoalkeeperWins": 0.0,
#                 "Goals": 1.6,
#                 "HomeOrAway": "AWAY",
#                 "Interceptions": 7.0,
#                 "IsGameOver": true,
#                 "LastManTackle": 0.0,
#                 "Minutes": 874.2,
#                 "Name": "AFC Ajax",
#                 "Offsides": 1.6,
#                 "Opponent": "SBV Vitesse",
#                 "OpponentId": 688,
#                 "OpponentScore": 1.6,
#                 "OwnGoals": 0.0,
#                 "Passes": 587.2,
#                 "PassesCompleted": 498.0,
#                 "PenaltiesConceded": 0.0,
#                 "PenaltiesWon": 0.0,
#                 "PenaltyKickGoals": 0.0,
#                 "PenaltyKickMisses": 0.0,
#                 "PenaltyKickSaves": 0.0,
#                 "Possession": 69.0,
#                 "RedCards": 0.0,
#                 "RoundId": 385,
#                 "Score": 1.6,
#                 "Season": 2020,
#                 "SeasonType": 1,
#                 "Shots": 23.0,
#                 "ShotsOnGoal": 7.0,
#                 "StatId": 1704838,
#                 "TacklesWon": 10.6,
#                 "Team": "AFC Ajax",
#                 "TeamId": 547,
#                 "Touches": 0.0,
#                 "Updated": "2019-11-14T19:20:33",
#                 "UpdatedUtc": "2019-11-15T00:20:33",
#                 "YellowCards": 2.3,
#                 "YellowRedCards": 0.0
#             },
#             {
#                 "Assists": 1.6,
#                 "BlockedShots": 2.3,
#                 "CornersWon": 0.0,
#                 "Crosses": 5.5,
#                 "DateTime": "2019-08-03T16:30:00",
#                 "Day": "2019-08-03T00:00:00",
#                 "DefenderCleanSheets": 0.0,
#                 "FantasyPoints": 81.0,
#                 "FantasyPointsDraftKings": 81.0,
#                 "FantasyPointsFanDuel": null,
#                 "FantasyPointsMondogoal": 11.2,
#                 "FantasyPointsYahoo": null,
#                 "Fouled": 11.5,
#                 "Fouls": 13.2,
#                 "GameId": 23013,
#                 "Games": 1,
#                 "GlobalGameId": 90023013,
#                 "GlobalOpponentId": 90000547,
#                 "GlobalTeamId": 90000688,
#                 "GoalkeeperCleanSheets": 0.0,
#                 "GoalkeeperGoalsAgainst": 1.6,
#                 "GoalkeeperSaves": 5.5,
#                 "GoalkeeperSingleGoalAgainst": 0.0,
#                 "GoalkeeperWins": 0.0,
#                 "Goals": 1.6,
#                 "HomeOrAway": "HOME",
#                 "Interceptions": 18.5,
#                 "IsGameOver": true,
#                 "LastManTackle": 0.0,
#                 "Minutes": 868.9,
#                 "Name": "SBV Vitesse",
#                 "Offsides": 0.0,
#                 "Opponent": "AFC Ajax",
#                 "OpponentId": 547,
#                 "OpponentScore": 1.6,
#                 "OwnGoals": 0.0,
#                 "Passes": 257.0,
#                 "PassesCompleted": 174.8,
#                 "PenaltiesConceded": 0.0,
#                 "PenaltiesWon": 0.0,
#                 "PenaltyKickGoals": 0.0,
#                 "PenaltyKickMisses": 0.0,
#                 "PenaltyKickSaves": 0.0,
#                 "Possession": 31.0,
#                 "RedCards": 0.0,
#                 "RoundId": 385,
#                 "Score": 1.6,
#                 "Season": 2020,
#                 "SeasonType": 1,
#                 "Shots": 11.5,
#                 "ShotsOnGoal": 2.3,
#                 "StatId": 1704839,
#                 "TacklesWon": 15.0,
#                 "Team": "SBV Vitesse",
#                 "TeamId": 688,
#                 "Touches": 0.0,
#                 "Updated": "2019-11-14T19:20:33",
#                 "UpdatedUtc": "2019-11-15T00:20:33",
#                 "YellowCards": 1.6,
#                 "YellowRedCards": 0.8
#             }
#         ],
#         "VideoAssistantReferee": null
#     }
# ]
