# %%
import requests
from sportmonks.soccer import SoccerApiV2

# %%
import json

def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# %%
soccer = SoccerApiV2(api_token='kDasthE00jpkFjEERAZNFyE9a79LNX3tPeaAqlhB3s2NhckJbKDhyL94j7AO')

# %%
#seizoen 2018/2019 = 2018-08-10 t/m 2019-05-12 
#seizoen id = 189
#Ajax = 629

# %%
fixtures = soccer.team_fixtures("2019-05-12", "2019-05-12", 629, includes=('localTeam', 'visitorTeam', 'lineup', 'substitutions', 'stats'))
sub_list = []
for f in fixtures:
    jprint(f['lineup'])
#     index = 0
#     while index < len(f['substitutions']):
#         sub = []
#         subbie = f['substitutions'][index]['player_out_name']
#         subbie_min = f['substitutions'][index]['minute']
#         sub.append(subbie)
#         sub.append(subbie_min)
#         sub_list.append(sub)
#         index += 1
# print(sub_list)

# print(sub_list[0][1])
# Out:
# [
#     {
#         "additional_position": null,
#         "captain": false,
#         "fixture_id": 10332049,
#         "formation_position": 1,
#         "number": 24,
#         "player_id": 26393,
#         "player_name": "Andr\u00e9 Onana",
#         "position": "G",
#         "posx": null,
#         "posy": null,
#         "stats": {
#             "cards": {
#                 "redcards": 0,
#                 "yellowcards": 0,
#                 "yellowredcards": null
#             },
#             "dribbles": {
#                 "attempts": 0,
#                 "dribbled_past": 0,
#                 "success": 0
#             },
#             "duels": {
#                 "total": 1,
#                 "won": 1
#             },
#             "fouls": {
#                 "committed": 0,
#                 "drawn": 0
#             },
#             "goals": {
#                 "assists": 0,
#                 "conceded": 1,
#                 "owngoals": 0,
#                 "scored": 0
# ...

# %%
# fixture = soccer.fixture(10332049, includes=('comments'))
# jprint(fixture['comments'])

# %%
lijst = []

#Get a list of all the fixture ids
list_id = []
ids = soccer.fixtures("2019-05-12", "2019-05-12")
for f in ids:
    if f['localteam_id'] == 629 or f['visitorteam_id'] == 629:
        id_fixture = f['id']
        list_id.append(id_fixture)
# print(list_id)

#Get a list of all the substitutes
fixtures = soccer.team_fixtures("2019-05-12", "2019-05-12", 629, includes=('localTeam', 'visitorTeam', 'lineup', 'substitutions', 'stats'))
sub_list = []
sub_list_min = []
for f in fixtures:
    indexx = 0
    while indexx < len(f['substitutions']):
        sub = []
        subbie = f['substitutions'][indexx]['player_out_id']
        subbie_min = f['substitutions'][indexx]['minute']
        injuried = f['substitutions'][indexx]['injuried']
        sub.append(subbie)
        sub.append(subbie_min)
        sub.append(injuried)
        sub_list_min.append(sub)
        sub_list.append(subbie)
        indexx += 1
# print(sub_list)

#Appending all the information to one list
fixtures = soccer.team_fixtures("2019-05-12", "2019-05-12", 629, includes=('localTeam', 'visitorTeam', 'lineup', 'substitutions', 'stats'))
index = 0
inhoud = ['Name', 'Position', 'Match_number', 'Match_minutes', 'Injuried']
lijst.append(inhoud)
for f in fixtures:
    while index < 11:
        speler = []
        minutes = 0
        if f['lineup'][index]['team_id'] == 629:
            id_ = f['lineup'][index]['fixture_id']
            match_number = list_id.index(id_) + 1

            speler.append(f['lineup'][index]['player_name'])
            speler.append(f['lineup'][index]['position'])
            speler.append(match_number)

            playerid = f['lineup'][index]['player_id']
            if playerid in sub_list:
                number = sub_list.index(playerid)
                minutes_played = sub_list_min[number][1]
                minutes += minutes_played
                if sub_list_min[number][2] == None:
                    injuried = 'No'
                else:
                    injuried = 'Yes'
                speler.append(minutes)
                speler.append(injuried)
            else:
                minutes += 90
                injuried = 'No'
                speler.append(minutes)
                speler.append(injuried)

            index += 1
            minutes = 0
            lijst.append(speler)

print(lijst)
# Out:
# [['Name', 'Position', 'Match_number', 'Match_minutes', 'Injuried'], ['André Onana', 'G', 1, 90, 'No'], ['Joël Veltman', 'D', 1, 90, 'No'], ['Matthijs De Ligt', 'D', 1, 90, 'No'], ['Daley Blind', 'D', 1, 90, 'No'], ['Nicolás Tagliafico', 'D', 1, 90, 'No'], ['Noussair Mazraoui', 'D', 1, 72, 'No'], ['Donny van de Beek', 'M', 1, 90, 'No'], ['Frenkie de Jong', 'M', 1, 90, 'No'], ['Hakim Ziyech', 'M', 1, 86, 'No'], ['Klaas-Jan Huntelaar', 'A', 1, 90, 'No'], ['Dušan Tadić', 'A', 1, 90, 'No']]

# %%
import xlsxwriter
with xlsxwriter.Workbook('ajaxtest.xlsx') as workbook:
    worksheet = workbook.add_worksheet()

    for row_num, data in enumerate(lijst):
        worksheet.write_row(row_num, 0, data)

# %%
# fixtures = soccer.team_fixtures("2019-05-12", "2019-05-12", 629, includes=('localTeam', 'visitorTeam', 'lineup', 'substitutions', 'stats'))
# for f in fixtures:
#         jprint(f['substitutions'][0])

# %%
# fixtures = soccer.team_stats(629)
# jprint(fixtures)

# %%
# #fixture id's list en dan kijken welke wedstrijd t is
# fixturess = soccer.fixtures("2019-05-12", "2019-05-12")
# for f in fixturess:
#     if f['localteam_id'] == 629 or f['visitorteam_id'] == 629:
#         jprint(f['id'])
# #     jprint(f)

# fixtures = soccer.team_fixtures("2019-05-12", "2019-05-12", 629, includes=('localTeam', 'visitorTeam', 'lineup', 'substitutions', 'stats'))
# for f in fixtures:
#     id_ = f['lineup'][0]['fixture_id']
#     print(id_)
#     print()

# # for f in fixturess:
# #     print(f)

# %%
dfs = pd.read_excel(ajaxtest.xlsx, sheet_name=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-182-dae09a9ddf6d> in <module>
# ----> 1 dfs = pd.read_excel(ajaxtest.xlsx, sheet_name=None)
#
# NameError: name 'pd' is not defined

# %%
fixtures = soccer.team_fixtures("2019-05-12", "2019-05-15", 629, includes=('localTeam', 'visitorTeam', 'lineup', 'substitutions', 'stats'))
for f in fixtures:
    id_ = f['substitutions']
    jprint(id_)
    break
# Out:
# [
#     {
#         "extra_minute": null,
#         "fixture_id": 10332049,
#         "id": 10332049007,
#         "injuried": null,
#         "minute": 46,
#         "player_in_id": 26966,
#         "player_in_name": "N. Venema",
#         "player_out_id": 608102,
#         "player_out_name": "O. Boussaid",
#         "team_id": "750",
#         "type": "subst"
#     },
#     {
#         "extra_minute": null,
#         "fixture_id": 10332049,
#         "id": 10332049009,
#         "injuried": true,
#         "minute": 58,
#         "player_in_id": 170471,
#         "player_in_name": "E. Bergstr\u00f6m",
#         "player_out_id": 24244,
#         "player_out_name": "T. Letschert",
#         "team_id": "750",
#         "type": "subst"
#     },
#     {
#         "extra_minute": null,
#         "fixture_id": 10332049,
#         "id": 10332049011,
#         "injuried": true,
#         "minute": 66,
#         "player_in_id": 33811,
#         "player_in_name": "L. G\u00f6rtler",
# ...
